# %% [markdown]
# # Tabulating All Issues
#
# Here we tabulate all the available issues and see if we can solve them in groups.

# %%
import pandas as pd

df = pd.read_csv('/storage/ttapera/RBC/PennLINC/Validation/HBN/validation.csv')
#df

# %% [markdown]
# The different issues to fix are:

# %%
df[['severity', 'type', 'files']].groupby(['severity', 'type']).agg(['count'])
# Out:
#                                                          files
#                                                          count
# severity type
# error    DWI_MISSING_BVAL                                    3
#          DWI_MISSING_BVEC                                    3
#          ECHO_TIME1-2_NOT_DEFINED                          340
#          EMPTY_FILE                                          3
#          INTERNAL ERROR                                      0
#          NIFTI_TOO_SMALL                                     2
#          NOT_INCLUDED                                     3424
#          PHASE_ENCODING_DIRECTION_MUST_DEFINE              122
#          REPETITION_TIME_MUST_DEFINE                       164
#          SLICETIMING_VALUES_GREATOR_THAN_REPETITION_TIME   138
#          TASK_NAME_MUST_DEFINE                             164
#          TOTAL_READOUT_TIME_MUST_DEFINE                    122
#          VOLUME_COUNT_MISMATCH                              25
# warning  EVENTS_TSV_MISSING                               8554
#          INCONSISTENT_PARAMETERS                           651
#          NO_AUTHORS                                          0
#          README_FILE_MISSING                                 0
#          SLICETIMING_ELEMENTS                                9
#          SLICE_TIMING_NOT_DEFINED                          164

# %%
df.loc[df['type'] == 'INTENDED_FOR', ['severity', 'type', 'files', 'description']]
