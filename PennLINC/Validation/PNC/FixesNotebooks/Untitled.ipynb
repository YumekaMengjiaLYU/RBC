# %% [markdown]
# # Fixing EchoTimes
#
# This notebook fixes echo time errors

# %%
import flywheel
import pandas as pd

client = flywheel.Client()

# %%
proj = client.projects.find_first('label=RBC_PNC')
df = pd.read_csv('/storage/ttapera/RBC/PennLINC/Validation/PNC/validation.csv')
echotimes_rows = df.loc[df['code'] == 15,]

# %%
echotimes_rows['subject'] = echotimes_rows['files'].str.extract(r'(sub-[0-9]+)')
# Out:
# /home/ttapera/miniconda3/envs/flywheel/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# We're going to confirm that these cases are all problematic because they have no fieldmaps to begin with

# %%
echotimes_rows
# Out:
#                                                    files  \
# 17183  /sub-1060668554/ses-PNC1/fmap/sub-1060668554_s...
# 17184  /sub-1095340536/ses-PNC1/fmap/sub-1095340536_s...
# 17185  /sub-1163553824/ses-PNC1/fmap/sub-1163553824_s...
# 17186  /sub-134279804/ses-PNC1/fmap/sub-134279804_ses...
# 17187  /sub-1512248949/ses-PNC1/fmap/sub-1512248949_s...
# 17188  /sub-1682850665/ses-PNC1/fmap/sub-1682850665_s...
# 17189  /sub-1867827374/ses-PNC1/fmap/sub-1867827374_s...
# 17190  /sub-2216595430/ses-PNC1/fmap/sub-2216595430_s...
# 17191  /sub-2441231201/ses-PNC1/fmap/sub-2441231201_s...
# 17192  /sub-255089519/ses-PNC1/fmap/sub-255089519_ses...
# 17193  /sub-3103368139/ses-PNC1/fmap/sub-3103368139_s...
# 17194  /sub-3260960488/ses-PNC1/fmap/sub-3260960488_s...
# 17195  /sub-3520758666/ses-PNC1/fmap/sub-3520758666_s...
# 17196  /sub-3925705705/ses-PNC1/fmap/sub-3925705705_s...
# 17197  /sub-398131152/ses-PNC1/fmap/sub-398131152_ses...
# ...
