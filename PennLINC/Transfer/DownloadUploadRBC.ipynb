# %% [markdown]
# Prep

# %%
import flywheel
import re
import sys
import os
import glob
import shutil
import nibabel as nb
import subprocess
import pandas as pd
from fw_heudiconv.cli import export
# Out:
# /storage/ttapera/fw-heudiconv/fw_heudiconv/backend_funcs/query.py:4: UserWarning: The DICOM readers are highly experimental, unstable, and only work for Siemens time-series at the moment
# Please use with caution.  We would be grateful for your help in improving them
#   from nibabel.nicom.dicomwrappers import wrapper_from_data
# 200603-21:08:33,765 nipype.utils INFO:
# 	 Running nipype version 1.4.0 (latest: 1.5.0)
# INFO: Running nipype version 1.4.0 (latest: 1.5.0)

# %% [markdown]
# Initialise flywheel data:

# %%
client = flywheel.Client()

RBC_proj = client.projects.find_first('label="ReproBrainChart"')

RBC_subjects = RBC_proj.subjects()

PNC_CS_proj = client.projects.find_first('label="PNC_CS_810336"')
PNC_LG_proj = client.projects.find_first('label="PNC_LG_810336"')

PNC_CS_subjects = PNC_CS_proj.subjects()
PNC_LG_subjects = PNC_LG_proj.subjects()

# get the penn_ids list
penn_ids = pd.read_csv('/storage/ttapera/RBC/data/bblid_renamed.csv', dtype = {'bblid': str, 'reid': str})

penn_ids['sub_id'] = 'sub-' + penn_ids['reid']

# %%
def in_pnc(row, PNC_CS_subjects=PNC_CS_subjects):
    
    all_subjects = [x.label for x in PNC_CS_subjects]
    if row['bblid'] in all_subjects:
        return True
    else:
        return False

# %%
# get the penn_ids list
penn_ids['process'] = penn_ids.apply(in_pnc, axis = 1)
penn_ids.to_csv('/storage/ttapera/RBC/data/bblids_2.csv', index=False)

# %%
# function to remove a subject from the RBC project
def remove_current_rbc_subject(row, RBC_subjects=RBC_subjects):

    target = [x for x in RBC_subjects if x.label == row['sub_id']]
    if len(target) == 1:
        print('found subject to remove: ', list(row), target[0].id)
        print('client.delete_subject(target[0].id)')
        return True
    else:
        return False

# %%
# get the penn_ids list
penn_ids['process'] = penn_ids.apply(remove_current_rbc_subject, axis = 1)
penn_ids.to_csv('/storage/ttapera/RBC/data/bblids_2.csv', index=False)
# Out:
# found subject to remove:  ['80179', '2216595430', 'sub-2216595430'] 5ed00a601a0c1d4b1f169f2c
# client.delete_subject(target[0].id)
# found subject to remove:  ['80199', '1867827374', 'sub-1867827374'] 5ed00e241a0c1d4b1b16a31d
# client.delete_subject(target[0].id)
# found subject to remove:  ['80208', '278814796', 'sub-278814796'] 5ed00f871a0c1d4b57169f2d
# client.delete_subject(target[0].id)
# found subject to remove:  ['80249', '3103368139', 'sub-3103368139'] 5ed011121a0c1d4baa16a062
# client.delete_subject(target[0].id)
# found subject to remove:  ['80263', '1654508502', 'sub-1654508502'] 5ed012b71a0c1d4bb516a07a
# client.delete_subject(target[0].id)
# found subject to remove:  ['80265', '1818459775', 'sub-1818459775'] 5ed014631a0c1d4bca169d2e
# client.delete_subject(target[0].id)
# found subject to remove:  ['80289', '2748427955', 'sub-2748427955'] 5ed0165b1a0c1d4bb9169f3c
# client.delete_subject(target[0].id)
# found subject to remove:  ['80373', '817266153', 'sub-817266153'] 5ed0187f1a0c1d48f616a154
# client.delete_subject(target[0].id)
# found subject to remove:  ['80396', '1344101127', 'sub-1344101127'] 5ed01a441a0c1d4bef16a136
# client.delete_subject(target[0].id)
# found subject to remove:  ['80603', '2312088658', 'sub-2312088658'] 5ed024571a0c1d4c6716a352
# client.delete_subject(target[0].id)
# found subject to remove:  ['80607', '1512248949', 'sub-1512248949'] 5ed025f31a0c1d4c7b16a2cb
# client.delete_subject(target[0].id)
# found subject to remove:  ['80680', '981492397', 'sub-981492397'] 5ed027ff1a0c1d49fd16a299
# client.delete_subject(target[0].id)
# found subject to remove:  ['80688', '277233792', 'sub-277233792'] 5ed029591a0c1d4cd8169b79
# client.delete_subject(target[0].id)
# found subject to remove:  ['80765', '360459346', 'sub-360459346'] 5ed02b161a0c1d4c9116a0ad
# client.delete_subject(target[0].id)
# found subject to remove:  ['80812', '3520758666', 'sub-3520758666'] 5ed02caa1a0c1d4d01169c68
# client.delete_subject(target[0].id)
# found subject to remove:  ['80854', '4066124203', 'sub-4066124203'] 5ed02f571a0c1d49fd16a598
# client.delete_subject(target[0].id)
# found subject to remove:  ['80889', '850131294', 'sub-850131294'] 5ed030dd1a0c1d4a4616a25d
# client.delete_subject(target[0].id)
# found subject to remove:  ['80895', '2508284118', 'sub-2508284118'] 5ed032b71a0c1d4ada169cde
# client.delete_subject(target[0].id)
# found subject to remove:  ['80961', '1163553824', 'sub-1163553824'] 5ed034d61a0c1d4d32169ee1
# client.delete_subject(target[0].id)
# found subject to remove:  ['81005', '255089519', 'sub-255089519'] 5ed036a61a0c1d4d2e16a4f2
# client.delete_subject(target[0].id)
# found subject to remove:  ['81043', '749926734', 'sub-749926734'] 5ed038631a0c1d4d84169c96
# client.delete_subject(target[0].id)
# found subject to remove:  ['81047', '4284367721', 'sub-4284367721'] 5ed03aa61a0c1d4dae169f84
# client.delete_subject(target[0].id)
# found subject to remove:  ['81098', '458296344', 'sub-458296344'] 5ed03c2b1a0c1d4dbe169c19
# client.delete_subject(target[0].id)
# found subject to remove:  ['81162', '997818717', 'sub-997818717'] 5ed03dda1a0c1d4dba169d17
# client.delete_subject(target[0].id)
# found subject to remove:  ['81222', '1498873540', 'sub-1498873540'] 5ed03f971a0c1d4dd316a0aa
# client.delete_subject(target[0].id)
# found subject to remove:  ['81231', '1604003015', 'sub-1604003015'] 5ed040e41a0c1d4dcf16a2ff
# client.delete_subject(target[0].id)
# found subject to remove:  ['81287', '813520934', 'sub-813520934'] 5ed0420b1a0c1d4ddc169fba
# client.delete_subject(target[0].id)
# found subject to remove:  ['81323', '4099541746', 'sub-4099541746'] 5ed043c41a0c1d4d6016a0ac
# client.delete_subject(target[0].id)
# found subject to remove:  ['81353', '2861717830', 'sub-2861717830'] 5ed0465e1a0c1d4e1d169efa
# client.delete_subject(target[0].id)
# found subject to remove:  ['81407', '2932582600', 'sub-2932582600'] 5ed048ae1a0c1d4d6016a649
# client.delete_subject(target[0].id)
# found subject to remove:  ['81456', '1483500237', 'sub-1483500237'] 5ed04a9b1a0c1d4e8516a4a2
# client.delete_subject(target[0].id)
# found subject to remove:  ['81462', '3704095570', 'sub-3704095570'] 5ed04c6b1a0c1d4ebb169ee6
# client.delete_subject(target[0].id)
# found subject to remove:  ['81521', '1006151876', 'sub-1006151876'] 5ed04de21a0c1d4ebb16a18e
# client.delete_subject(target[0].id)
# found subject to remove:  ['81528', '1829488364', 'sub-1829488364'] 5ed04f711a0c1d4be616a22f
# client.delete_subject(target[0].id)
# found subject to remove:  ['81533', '1103118018', 'sub-1103118018'] 5ed051911a0c1d4b9a16a564
# client.delete_subject(target[0].id)
# found subject to remove:  ['81544', '1828951258', 'sub-1828951258'] 5ed053d81a0c1d4ebf16a383
# client.delete_subject(target[0].id)
# found subject to remove:  ['81595', '2299321259', 'sub-2299321259'] 5ed056211a0c1d4ed416a2ab
# client.delete_subject(target[0].id)
# found subject to remove:  ['81604', '2441231201', 'sub-2441231201'] 5ed057cd1a0c1d4f95169fb1
# client.delete_subject(target[0].id)
# found subject to remove:  ['81644', '3170512105', 'sub-3170512105'] 5ed0599b1a0c1d4f6216a1b1
# client.delete_subject(target[0].id)
# found subject to remove:  ['81659', '1730541924', 'sub-1730541924'] 5ed05ae91a0c1d4fca169b4b
# client.delete_subject(target[0].id)
# found subject to remove:  ['81662', '1114035056', 'sub-1114035056'] 5ed05cda1a0c1d4fce169fa6
# client.delete_subject(target[0].id)
# found subject to remove:  ['81705', '2720014197', 'sub-2720014197'] 5ed05f151a0c1d4ffa169b1a
# client.delete_subject(target[0].id)
# found subject to remove:  ['81725', '1380078917', 'sub-1380078917'] 5ed0611a1a0c1d4ea616a3a3
# client.delete_subject(target[0].id)
# found subject to remove:  ['81754', '1887390452', 'sub-1887390452'] 5ed0632a1a0c1d502f169e38
# client.delete_subject(target[0].id)
# found subject to remove:  ['81760', '4108002155', 'sub-4108002155'] 5ed064ed1a0c1d4fd616a5d4
# client.delete_subject(target[0].id)
# found subject to remove:  ['81826', '1060668554', 'sub-1060668554'] 5ed067241a0c1d4ffa16a5ac
# client.delete_subject(target[0].id)
# found subject to remove:  ['81855', '3840869169', 'sub-3840869169'] 5ed069161a0c1d507a16a591
# client.delete_subject(target[0].id)
# found subject to remove:  ['81865', '2539603725', 'sub-2539603725'] 5ed06afa1a0c1d4d3a16a5c6
# client.delete_subject(target[0].id)
# found subject to remove:  ['81876', '2442304782', 'sub-2442304782'] 5ed06cd41a0c1d509016a278
# client.delete_subject(target[0].id)
# found subject to remove:  ['81903', '200066829', 'sub-200066829'] 5ed06edf1a0c1d508816a5d9
# client.delete_subject(target[0].id)
# found subject to remove:  ['81906', '2148378283', 'sub-2148378283'] 5ed070c21a0c1d4ea116a1b9
# client.delete_subject(target[0].id)
# found subject to remove:  ['81939', '1381671196', 'sub-1381671196'] 5ed074011a0c1d50c516a411
# client.delete_subject(target[0].id)
# found subject to remove:  ['81982', '1095340536', 'sub-1095340536'] 5ed075e51a0c1d5168169b39
# client.delete_subject(target[0].id)
# found subject to remove:  ['81989', '398131152', 'sub-398131152'] 5ed077a71a0c1d4d8416a5eb
# client.delete_subject(target[0].id)
# found subject to remove:  ['81992', '3264978932', 'sub-3264978932'] 5ed079b71a0c1d51a7169b5b
# client.delete_subject(target[0].id)
# found subject to remove:  ['82003', '3204472167', 'sub-3204472167'] 5ed07b931a0c1d5196169efe
# client.delete_subject(target[0].id)
# found subject to remove:  ['82021', '3062402909', 'sub-3062402909'] 5ed07db31a0c1d4fc2169e73
# client.delete_subject(target[0].id)
# found subject to remove:  ['82039', '3870702454', 'sub-3870702454'] 5ed07fc51a0c1d51e7169fbc
# client.delete_subject(target[0].id)
# found subject to remove:  ['82051', '3896564969', 'sub-3896564969'] 5ed081a31a0c1d520b169dc3
# client.delete_subject(target[0].id)
# found subject to remove:  ['82063', '1645871327', 'sub-1645871327'] 5ed082f11a0c1d519e16a506
# client.delete_subject(target[0].id)
# found subject to remove:  ['82096', '2170759229', 'sub-2170759229'] 5ed085681a0c1d4fed16a461
# client.delete_subject(target[0].id)
# found subject to remove:  ['82124', '2788528349', 'sub-2788528349'] 5ed086c61a0c1d5247169b48
# client.delete_subject(target[0].id)
# found subject to remove:  ['82155', '2215153516', 'sub-2215153516'] 5ed088ab1a0c1d5247169e91
# client.delete_subject(target[0].id)
# found subject to remove:  ['82202', '402523989', 'sub-402523989'] 5ed08aa61a0c1d523316a67c
# client.delete_subject(target[0].id)
# found subject to remove:  ['82208', '3289562482', 'sub-3289562482'] 5ed08c2a1a0c1d523716a55a
# client.delete_subject(target[0].id)
# found subject to remove:  ['82217', '993394555', 'sub-993394555'] 5ed08db71a0c1d52bb169c02
# client.delete_subject(target[0].id)
# found subject to remove:  ['82229', '2976850765', 'sub-2976850765'] 5ed08fe41a0c1d52d5169cf4
# client.delete_subject(target[0].id)
# found subject to remove:  ['82232', '1682850665', 'sub-1682850665'] 5ed091f31a0c1d52ec169aed
# client.delete_subject(target[0].id)
# found subject to remove:  ['82281', '2763114922', 'sub-2763114922'] 5ed093df1a0c1d52fc169c5e
# client.delete_subject(target[0].id)
# found subject to remove:  ['82293', '3733544876', 'sub-3733544876'] 5ed095781a0c1d52f8169eb7
# client.delete_subject(target[0].id)
# found subject to remove:  ['82311', '3234489701', 'sub-3234489701'] 5ed097641a0c1d52e516a2ea
# client.delete_subject(target[0].id)
# found subject to remove:  ['82359', '1046399178', 'sub-1046399178'] 5ed09a671a0c1d502416a002
# client.delete_subject(target[0].id)
# found subject to remove:  ['82373', '3829047511', 'sub-3829047511'] 5ed09c221a0c1d531b16a219
# client.delete_subject(target[0].id)
# found subject to remove:  ['82383', '2359486867', 'sub-2359486867'] 5ed09e231a0c1d5390169bb3
# client.delete_subject(target[0].id)
# found subject to remove:  ['82423', '865069950', 'sub-865069950'] 5ed09ffa1a0c1d53a6169b66
# client.delete_subject(target[0].id)
# found subject to remove:  ['82453', '1833416906', 'sub-1833416906'] 5ed0a1cb1a0c1d53c6169b09
# client.delete_subject(target[0].id)
# found subject to remove:  ['82458', '3260960488', 'sub-3260960488'] 5ed0a3761a0c1d53be169fc5
# client.delete_subject(target[0].id)
# found subject to remove:  ['82467', '3441116881', 'sub-3441116881'] 5ed0a55b1a0c1d53ec169a60
# client.delete_subject(target[0].id)
# found subject to remove:  ['82489', '3753613715', 'sub-3753613715'] 5ed0a8591a0c1d53cf16a016
# client.delete_subject(target[0].id)
# found subject to remove:  ['82492', '177928631', 'sub-177928631'] 5ed0aa2b1a0c1d544f169b12
# client.delete_subject(target[0].id)
# found subject to remove:  ['82511', '4135739225', 'sub-4135739225'] 5ed0ac0c1a0c1d545716a067
# client.delete_subject(target[0].id)
# found subject to remove:  ['82587', '1762027912', 'sub-1762027912'] 5ed0ad861a0c1d53ec16a533
# client.delete_subject(target[0].id)
# found subject to remove:  ['82674', '1904270196', 'sub-1904270196'] 5ed0aef01a0c1d545316a4a0
# client.delete_subject(target[0].id)
# found subject to remove:  ['82709', '940718928', 'sub-940718928'] 5ed0b1211a0c1d515b16a548
# client.delete_subject(target[0].id)
# found subject to remove:  ['82746', '3029167955', 'sub-3029167955'] 5ed0b2e11a0c1d54a2169c22
# client.delete_subject(target[0].id)
# found subject to remove:  ['82754', '3468032341', 'sub-3468032341'] 5ed0b5f21a0c1d519a16a037
# client.delete_subject(target[0].id)
# found subject to remove:  ['82784', '1448081953', 'sub-1448081953'] 5ed0b7ec1a0c1d546d16a089
# client.delete_subject(target[0].id)
# found subject to remove:  ['82790', '579459470', 'sub-579459470'] 5ed0b9921a0c1d549916a598
# client.delete_subject(target[0].id)
# found subject to remove:  ['82825', '82699044', 'sub-82699044'] 5ed0bc501a0c1d5545169aff
# client.delete_subject(target[0].id)
# found subject to remove:  ['82877', '2002122030', 'sub-2002122030'] 5ed0be0f1a0c1d522216a28a
# client.delete_subject(target[0].id)
# found subject to remove:  ['82907', '1724567179', 'sub-1724567179'] 5ed0bf9b1a0c1d4f5e16a109
# client.delete_subject(target[0].id)
# found subject to remove:  ['82914', '1157595916', 'sub-1157595916'] 5ed0c1eb1a0c1d522216a6f8
# client.delete_subject(target[0].id)
# found subject to remove:  ['82935', '3362293049', 'sub-3362293049'] 5ed0c4c91a0c1d55ab169e9d
# client.delete_subject(target[0].id)
# found subject to remove:  ['82940', '490845995', 'sub-490845995'] 5ed0c5f91a0c1d55d5169a65
# client.delete_subject(target[0].id)
# found subject to remove:  ['82962', '348742929', 'sub-348742929'] 5ed0c7331a0c1d547816a543
# client.delete_subject(target[0].id)
# found subject to remove:  ['82982', '4286784089', 'sub-4286784089'] 5ed0c8e81a0c1d52af16a30f
# client.delete_subject(target[0].id)
# found subject to remove:  ['82985', '2374556661', 'sub-2374556661'] 5ed0cacf1a0c1d52af16a5e1
# client.delete_subject(target[0].id)
# found subject to remove:  ['82989', '2842709105', 'sub-2842709105'] 5ed0cc7b1a0c1d52ab16a653
# client.delete_subject(target[0].id)
# found subject to remove:  ['83010', '3549161979', 'sub-3549161979'] 5ed0ce4d1a0c1d560c16a00e
# client.delete_subject(target[0].id)
# found subject to remove:  ['83013', '1452555764', 'sub-1452555764'] 5ed0d0171a0c1d5618169c0b
# client.delete_subject(target[0].id)
# found subject to remove:  ['83035', '2819146349', 'sub-2819146349'] 5ed0d1b31a0c1d5621169b6e
# client.delete_subject(target[0].id)
# found subject to remove:  ['83044', '2318786012', 'sub-2318786012'] 5ed0d39d1a0c1d560816a4e5
# client.delete_subject(target[0].id)
# found subject to remove:  ['83080', '1711930631', 'sub-1711930631'] 5ed0d55b1a0c1d548016a502
# client.delete_subject(target[0].id)
# found subject to remove:  ['83103', '1310346718', 'sub-1310346718'] 5ed0d7181a0c1d566f169e67
# client.delete_subject(target[0].id)
# found subject to remove:  ['83113', '3452453842', 'sub-3452453842'] 5ed0d99c1a0c1d4f5e16a664
# client.delete_subject(target[0].id)
# found subject to remove:  ['83127', '1838464457', 'sub-1838464457'] 5ed0db1a1a0c1d56a4169cfc
# client.delete_subject(target[0].id)
# found subject to remove:  ['83207', '3533807592', 'sub-3533807592'] 5ed0dc661a0c1d56b1169dc6
# client.delete_subject(target[0].id)
# found subject to remove:  ['83253', '2951167051', 'sub-2951167051'] 5ed0de1d1a0c1d568216a304
# client.delete_subject(target[0].id)
# found subject to remove:  ['83322', '1545837513', 'sub-1545837513'] 5ed0e0471a0c1d56b516a294
# client.delete_subject(target[0].id)
# found subject to remove:  ['83328', '2412716526', 'sub-2412716526'] 5ed0e1fb1a0c1d56b916a09c
# client.delete_subject(target[0].id)
# found subject to remove:  ['83339', '2298674157', 'sub-2298674157'] 5ed0e3b21a0c1d56ac16a62f
# client.delete_subject(target[0].id)
# found subject to remove:  ['83358', '3506926170', 'sub-3506926170'] 5ed0e56e1a0c1d542f16a122
# client.delete_subject(target[0].id)
# found subject to remove:  ['83372', '4069098061', 'sub-4069098061'] 5ed0e7241a0c1d542f16a5f2
# client.delete_subject(target[0].id)
# found subject to remove:  ['83423', '1506379233', 'sub-1506379233'] 5ed0e9041a0c1d571116a156
# client.delete_subject(target[0].id)
# found subject to remove:  ['83429', '1942988748', 'sub-1942988748'] 5ed0eb211a0c1d577c169be7
# client.delete_subject(target[0].id)
# found subject to remove:  ['83454', '1963601913', 'sub-1963601913'] 5ed0ecf51a0c1d54d1169f3d
# client.delete_subject(target[0].id)
# found subject to remove:  ['83525', '408967257', 'sub-408967257'] 5ed0ee991a0c1d575e16a2e2
# client.delete_subject(target[0].id)
# found subject to remove:  ['83531', '1822850038', 'sub-1822850038'] 5ed0f0411a0c1d57cb169d40
# client.delete_subject(target[0].id)
# found subject to remove:  ['83580', '1437821247', 'sub-1437821247'] 5ed0f1e91a0c1d55e616a43f
# client.delete_subject(target[0].id)
# found subject to remove:  ['83612', '3357695482', 'sub-3357695482'] 5ed0f3b91a0c1d57d3169e7e
# client.delete_subject(target[0].id)
# found subject to remove:  ['83616', '1060532313', 'sub-1060532313'] 5ed0f55a1a0c1d57f6169c9e
# client.delete_subject(target[0].id)
# found subject to remove:  ['83632', '943724490', 'sub-943724490'] 5ed0f73d1a0c1d57e9169d24
# client.delete_subject(target[0].id)
# found subject to remove:  ['83648', '3043294809', 'sub-3043294809'] 5ed0f91b1a0c1d580f169f4b
# client.delete_subject(target[0].id)
# found subject to remove:  ['83708', '3612049856', 'sub-3612049856'] 5ed0fbf31a0c1d57ed16a3e5
# client.delete_subject(target[0].id)
# found subject to remove:  ['83832', '2675079707', 'sub-2675079707'] 5ed0feeb1a0c1d58aa169e1e
# client.delete_subject(target[0].id)
# found subject to remove:  ['83835', '3984163767', 'sub-3984163767'] 5ed100711a0c1d58a616a217
# client.delete_subject(target[0].id)
# found subject to remove:  ['83937', '2134697000', 'sub-2134697000'] 5ed1024c1a0c1d57fb16a553
# client.delete_subject(target[0].id)
# found subject to remove:  ['83972', '4250731906', 'sub-4250731906'] 5ed1045f1a0c1d58d8169f50
# client.delete_subject(target[0].id)
# found subject to remove:  ['83987', '987544292', 'sub-987544292'] 5ed106621a0c1d549d16a5a7
# client.delete_subject(target[0].id)
# found subject to remove:  ['83990', '4026391232', 'sub-4026391232'] 5ed108141a0c1d58eb16a11f
# client.delete_subject(target[0].id)
# found subject to remove:  ['83999', '1088695522', 'sub-1088695522'] 5ed10ab71a0c1d58eb16a494
# client.delete_subject(target[0].id)
# found subject to remove:  ['84002', '3131141015', 'sub-3131141015'] 5ed10c931a0c1d562116a3ec
# client.delete_subject(target[0].id)
# found subject to remove:  ['84050', '3991005721', 'sub-3991005721'] 5ed10e8f1a0c1d5993169e35
# client.delete_subject(target[0].id)
# found subject to remove:  ['84053', '1761492502', 'sub-1761492502'] 5ed10fb21a0c1d59a3169ac1
# client.delete_subject(target[0].id)
# found subject to remove:  ['84059', '1123556411', 'sub-1123556411'] 5ed1118f1a0c1d599f169da9
# client.delete_subject(target[0].id)
# found subject to remove:  ['84069', '826824711', 'sub-826824711'] 5ed113501a0c1d59a516a242
# client.delete_subject(target[0].id)
# found subject to remove:  ['84096', '4164375240', 'sub-4164375240'] 5ed1140c1a0c1d598316a5d7
# client.delete_subject(target[0].id)
# found subject to remove:  ['84103', '1560828340', 'sub-1560828340'] 5ed115651a0c1d599b16a0ab
# client.delete_subject(target[0].id)
# found subject to remove:  ['84107', '2397365139', 'sub-2397365139'] 5ed117861a0c1d59b716a112
# client.delete_subject(target[0].id)
# found subject to remove:  ['84136', '2774105134', 'sub-2774105134'] 5ed1194e1a0c1d59bb169fec
# client.delete_subject(target[0].id)
# found subject to remove:  ['84171', '4197093898', 'sub-4197093898'] 5ed11b1a1a0c1d5a36169a95
# client.delete_subject(target[0].id)
# found subject to remove:  ['84203', '308228517', 'sub-308228517'] 5ed11cdd1a0c1d57df169e8b
# client.delete_subject(target[0].id)
# found subject to remove:  ['84233', '1643083161', 'sub-1643083161'] 5ed11e971a0c1d5a49169ee3
# client.delete_subject(target[0].id)
# found subject to remove:  ['84258', '334290435', 'sub-334290435'] 5ed1212f1a0c1d5a1d16a47c
# client.delete_subject(target[0].id)
# found subject to remove:  ['84288', '2333531511', 'sub-2333531511'] 5ed122cd1a0c1d5a65169c95
# client.delete_subject(target[0].id)
# found subject to remove:  ['84321', '3392035756', 'sub-3392035756'] 5ed1247d1a0c1d573b16a2dc
# client.delete_subject(target[0].id)
# found subject to remove:  ['84332', '3437461935', 'sub-3437461935'] 5ed125ac1a0c1d5a7516a05b
# client.delete_subject(target[0].id)
# found subject to remove:  ['84354', '520579518', 'sub-520579518'] 5ed127471a0c1d5a7116a4fb
# client.delete_subject(target[0].id)
# found subject to remove:  ['84356', '3874353588', 'sub-3874353588'] 5ed128ad1a0c1d5aa0169a71
# client.delete_subject(target[0].id)
# found subject to remove:  ['84365', '272785799', 'sub-272785799'] 5ed12a621a0c1d5a6916a2ff
# client.delete_subject(target[0].id)
# found subject to remove:  ['84371', '1686389288', 'sub-1686389288'] 5ed12c8e1a0c1d5ab3169cad
# client.delete_subject(target[0].id)
# found subject to remove:  ['84385', '4211615439', 'sub-4211615439'] 5ed12e2f1a0c1d5ac5169f17
# client.delete_subject(target[0].id)
# found subject to remove:  ['84394', '70214854', 'sub-70214854'] 5ed12fda1a0c1d5ac916a0e5
# client.delete_subject(target[0].id)
# found subject to remove:  ['84446', '471903637', 'sub-471903637'] 5ec3579f1a0c1d05f816a193
# client.delete_subject(target[0].id)
# found subject to remove:  ['84476', '1871767977', 'sub-1871767977'] 5ec35ccd1a0c1d060f169df7
# client.delete_subject(target[0].id)
# found subject to remove:  ['84508', '1526154632', 'sub-1526154632'] 5ec3616a1a0c1d062116a12e
# client.delete_subject(target[0].id)
# found subject to remove:  ['84511', '2413176236', 'sub-2413176236'] 5ec365771a0c1d063316a037
# client.delete_subject(target[0].id)
# found subject to remove:  ['84525', '192039987', 'sub-192039987'] 5ec36a991a0c1d0657169bda
# client.delete_subject(target[0].id)
# found subject to remove:  ['84535', '2292204095', 'sub-2292204095'] 5ec36f311a0c1d066b169e05
# client.delete_subject(target[0].id)
# found subject to remove:  ['84659', '2696622128', 'sub-2696622128'] 5ec373861a0c1d0683169cae
# client.delete_subject(target[0].id)
# found subject to remove:  ['84685', '481928384', 'sub-481928384'] 5ec379151a0c1d069b169b0a
# client.delete_subject(target[0].id)
# found subject to remove:  ['84688', '3177113419', 'sub-3177113419'] 5ec385831a0c1d0700169da5
# client.delete_subject(target[0].id)
# found subject to remove:  ['84732', '1678076849', 'sub-1678076849'] 5ec389fe1a0c1d0720169fc7
# client.delete_subject(target[0].id)
# found subject to remove:  ['84735', '370053661', 'sub-370053661'] 5ec38ebd1a0c1d0758169af1
# client.delete_subject(target[0].id)
# found subject to remove:  ['84758', '1794346030', 'sub-1794346030'] 5ec393e01a0c1d0784169ad7
# client.delete_subject(target[0].id)
# found subject to remove:  ['84761', '1336976954', 'sub-1336976954'] 5ec39e131a0c1d07f116a010
# client.delete_subject(target[0].id)
# found subject to remove:  ['84803', '2200266312', 'sub-2200266312'] 5ec3a2e11a0c1d0821169e27
# client.delete_subject(target[0].id)
# found subject to remove:  ['84814', '1929155048', 'sub-1929155048'] 5ec3a4351a0c1d0829169ff5
# client.delete_subject(target[0].id)
# found subject to remove:  ['84816', '2333477346', 'sub-2333477346'] 5ec3a88f1a0c1d0855169b1c
# client.delete_subject(target[0].id)
# found subject to remove:  ['84891', '3477990078', 'sub-3477990078'] 5ec3add71a0c1d087d169e3d
# client.delete_subject(target[0].id)
# found subject to remove:  ['84970', '396724706', 'sub-396724706'] 5ec3b8351a0c1d08d9169d86
# client.delete_subject(target[0].id)
# found subject to remove:  ['84973', '2461687277', 'sub-2461687277'] 5ec3c1a11a0c1d08f116a257
# client.delete_subject(target[0].id)
# found subject to remove:  ['85005', '2733440164', 'sub-2733440164'] 5ec3c7c21a0c1d093516a391
# client.delete_subject(target[0].id)
# found subject to remove:  ['85054', '1890822437', 'sub-1890822437'] 5ec3cbf71a0c1d093916a63a
# client.delete_subject(target[0].id)
# found subject to remove:  ['85057', '3512003246', 'sub-3512003246'] 5ec3d15d1a0c1d095116a1cf
# client.delete_subject(target[0].id)
# found subject to remove:  ['85063', '1896354997', 'sub-1896354997'] 5ec3df2f1a0c1d09b916a36d
# client.delete_subject(target[0].id)
# found subject to remove:  ['85083', '2588038141', 'sub-2588038141'] 5ec3ec201a0c1d0a1e169ca6
# client.delete_subject(target[0].id)
# found subject to remove:  ['85139', '1861767482', 'sub-1861767482'] 5ec3f0c81a0c1d0a36169d52
# client.delete_subject(target[0].id)
# found subject to remove:  ['85159', '3017936002', 'sub-3017936002'] 5ec3f5e61a0c1d0a52169af4
# client.delete_subject(target[0].id)
# found subject to remove:  ['85165', '3836403514', 'sub-3836403514'] 5ec3fac61a0c1d0a6316a032
# client.delete_subject(target[0].id)
# found subject to remove:  ['85173', '1770415263', 'sub-1770415263'] 5ec404de1a0c1d0a9b169a71
# client.delete_subject(target[0].id)
# found subject to remove:  ['85230', '2394345225', 'sub-2394345225'] 5ec4098e1a0c1d0ab0169d47
# client.delete_subject(target[0].id)
# found subject to remove:  ['85258', '2041229468', 'sub-2041229468'] 5ec40e651a0c1d0ad2169f68
# client.delete_subject(target[0].id)
# found subject to remove:  ['85286', '3316130924', 'sub-3316130924'] 5ec414631a0c1d0a3a16a389
# client.delete_subject(target[0].id)
# found subject to remove:  ['85369', '1593612444', 'sub-1593612444'] 5ec421cc1a0c1d0b2c16a360
# client.delete_subject(target[0].id)
# found subject to remove:  ['85392', '1620557808', 'sub-1620557808'] 5ec42b671a0c1d0b67169f67
# client.delete_subject(target[0].id)
# found subject to remove:  ['85394', '1852377689', 'sub-1852377689'] 5ec430021a0c1d0b8f169e0a
# client.delete_subject(target[0].id)
# found subject to remove:  ['85397', '3482208722', 'sub-3482208722'] 5ec43a041a0c1d0bba169e01
# client.delete_subject(target[0].id)
# found subject to remove:  ['85400', '1440768299', 'sub-1440768299'] 5ec447091a0c1d0c0e169ee9
# client.delete_subject(target[0].id)
# found subject to remove:  ['85412', '802748205', 'sub-802748205'] 5ec455811a0c1d0c56169a46
# client.delete_subject(target[0].id)
# found subject to remove:  ['85433', '2739925272', 'sub-2739925272'] 5ec45a871a0c1d0c6a169ab4
# client.delete_subject(target[0].id)
# found subject to remove:  ['85464', '2146308400', 'sub-2146308400'] 5ec4608e1a0c1d0c89169e57
# client.delete_subject(target[0].id)
# found subject to remove:  ['85483', '3870273492', 'sub-3870273492'] 5ec466361a0c1d0ca2169c0c
# client.delete_subject(target[0].id)
# found subject to remove:  ['85547', '1631350938', 'sub-1631350938'] 5ec467711a0c1d0caa169b80
# client.delete_subject(target[0].id)
# found subject to remove:  ['85603', '1313957126', 'sub-1313957126'] 5ec46e1a1a0c1d0cc2169f40
# client.delete_subject(target[0].id)
# found subject to remove:  ['85632', '1091857727', 'sub-1091857727'] 5ec477db1a0c1d0cde16a217
# client.delete_subject(target[0].id)
# found subject to remove:  ['85679', '983504031', 'sub-983504031'] 5ec482e21a0c1d0d1f169e61
# client.delete_subject(target[0].id)
# found subject to remove:  ['85715', '2351609522', 'sub-2351609522'] 5ec48dca1a0c1d0d3716a02c
# client.delete_subject(target[0].id)
# found subject to remove:  ['85743', '746461855', 'sub-746461855'] 5ec493021a0c1d0d57169f6e
# client.delete_subject(target[0].id)
# found subject to remove:  ['85751', '1447464089', 'sub-1447464089'] 5ec498311a0c1d0d6b169f14
# client.delete_subject(target[0].id)
# found subject to remove:  ['85765', '3538085126', 'sub-3538085126'] 5ec49d031a0c1d0d67169f0b
# client.delete_subject(target[0].id)
# found subject to remove:  ['85812', '373574366', 'sub-373574366'] 5ec4a3a81a0c1d0d3716a242
# client.delete_subject(target[0].id)
# found subject to remove:  ['85822', '1710493410', 'sub-1710493410'] 5ec4a9621a0c1d0dbb169ee2
# client.delete_subject(target[0].id)
# found subject to remove:  ['85853', '1204359507', 'sub-1204359507'] 5ec4b47a1a0c1d0de3169db8
# client.delete_subject(target[0].id)
# found subject to remove:  ['85862', '1217141098', 'sub-1217141098'] 5ec4b8ea1a0c1d0dff169bf9
# client.delete_subject(target[0].id)
# found subject to remove:  ['85876', '1011497669', 'sub-1011497669'] 5ec4c2ed1a0c1d0df316a173
# client.delete_subject(target[0].id)
# found subject to remove:  ['85902', '3670092995', 'sub-3670092995'] 5ec4c8591a0c1d0e3716a19e
# client.delete_subject(target[0].id)
# found subject to remove:  ['85948', '609583468', 'sub-609583468'] 5ec4cd511a0c1d0e4816a1b9
# client.delete_subject(target[0].id)
# found subject to remove:  ['85960', '4264683889', 'sub-4264683889'] 5ec4d5621a0c1d0e6816a139
# client.delete_subject(target[0].id)
# found subject to remove:  ['85980', '360427065', 'sub-360427065'] 5ec4e0cc1a0c1d0ea8169c5f
# client.delete_subject(target[0].id)
# found subject to remove:  ['85983', '2422503990', 'sub-2422503990'] 5ec4e9cd1a0c1d0ebc16a1b8
# client.delete_subject(target[0].id)
# found subject to remove:  ['86061', '908607262', 'sub-908607262'] 5ec4f3e51a0c1d0edc169fad
# client.delete_subject(target[0].id)
# found subject to remove:  ['86076', '3354511550', 'sub-3354511550'] 5ec4f89b1a0c1d0ee4169b7d
# client.delete_subject(target[0].id)
# found subject to remove:  ['86126', '4060589852', 'sub-4060589852'] 5ec501bc1a0c1d0efc169c0f
# client.delete_subject(target[0].id)
# found subject to remove:  ['86162', '678139191', 'sub-678139191'] 5ec506f81a0c1d0ee8169f80
# client.delete_subject(target[0].id)
# found subject to remove:  ['86171', '782651188', 'sub-782651188'] 5ec50c8d1a0c1d0f04169f29
# client.delete_subject(target[0].id)
# found subject to remove:  ['86212', '972336786', 'sub-972336786'] 5ec511ab1a0c1d0f1c169fc4
# client.delete_subject(target[0].id)
# found subject to remove:  ['86252', '344766746', 'sub-344766746'] 5ec51bd71a0c1d0f44169b2f
# client.delete_subject(target[0].id)
# found subject to remove:  ['86287', '594496588', 'sub-594496588'] 5ec525391a0c1d0f60169b49
# client.delete_subject(target[0].id)
# found subject to remove:  ['86303', '388650152', 'sub-388650152'] 5ec52ea11a0c1d0f74169eef
# client.delete_subject(target[0].id)
# found subject to remove:  ['86350', '1017092387', 'sub-1017092387'] 5ec534071a0c1d0f9416aa42
# client.delete_subject(target[0].id)
# found subject to remove:  ['86435', '326891280', 'sub-326891280'] 5ec538691a0c1d0fb0169e1e
# client.delete_subject(target[0].id)
# found subject to remove:  ['86440', '3327313154', 'sub-3327313154'] 5ec53d9a1a0c1d0fd816a286
# client.delete_subject(target[0].id)
# found subject to remove:  ['86444', '826730657', 'sub-826730657'] 5ec5479b1a0c1d1024169fe6
# client.delete_subject(target[0].id)
# found subject to remove:  ['86460', '909152050', 'sub-909152050'] 5ec54c421a0c1d1055169dd9
# client.delete_subject(target[0].id)
# found subject to remove:  ['86486', '3548675539', 'sub-3548675539'] 5ec556501a0c1d109e169f99
# client.delete_subject(target[0].id)
# found subject to remove:  ['86506', '2860715826', 'sub-2860715826'] 5ec55c711a0c1d10d6169db0
# client.delete_subject(target[0].id)
# found subject to remove:  ['86514', '3501955380', 'sub-3501955380'] 5ec560a01a0c1d10da16a031
# client.delete_subject(target[0].id)
# found subject to remove:  ['86517', '1901910719', 'sub-1901910719'] 5ec565811a0c1d10ee169a4f
# client.delete_subject(target[0].id)
# found subject to remove:  ['86583', '389182564', 'sub-389182564'] 5ec56a301a0c1d110e169ae9
# client.delete_subject(target[0].id)
# found subject to remove:  ['86626', '2333670705', 'sub-2333670705'] 5ec5785a1a0c1d113a169b9c
# client.delete_subject(target[0].id)
# found subject to remove:  ['86633', '2200670875', 'sub-2200670875'] 5ec57dc21a0c1d10ee169ed5
# client.delete_subject(target[0].id)
# found subject to remove:  ['86690', '3221624404', 'sub-3221624404'] 5ec584c11a0c1d115a16a2c8
# client.delete_subject(target[0].id)
# found subject to remove:  ['86707', '1814037649', 'sub-1814037649'] 5ec58a391a0c1d1166169e7e
# client.delete_subject(target[0].id)
# found subject to remove:  ['86722', '861649027', 'sub-861649027'] 5ec5956b1a0c1d1195169db2
# client.delete_subject(target[0].id)
# found subject to remove:  ['86769', '1221640483', 'sub-1221640483'] 5ec59a291a0c1d119916a013
# client.delete_subject(target[0].id)
# found subject to remove:  ['86820', '584328521', 'sub-584328521'] 5ec5a2a81a0c1d11b9169eae
# client.delete_subject(target[0].id)
# found subject to remove:  ['86853', '4177765106', 'sub-4177765106'] 5ec5a93f1a0c1d11d1169d87
# client.delete_subject(target[0].id)
# found subject to remove:  ['86880', '3840308617', 'sub-3840308617'] 5ec5ae4f1a0c1d11de16a0ff
# client.delete_subject(target[0].id)
# found subject to remove:  ['86921', '292946269', 'sub-292946269'] 5ec5b6881a0c1d1202169a81
# client.delete_subject(target[0].id)
# found subject to remove:  ['86924', '2593612027', 'sub-2593612027'] 5ec5c1461a0c1d11c516a05e
# client.delete_subject(target[0].id)
# found subject to remove:  ['86946', '3194463561', 'sub-3194463561'] 5ec5d2d51a0c1d11b516a011
# client.delete_subject(target[0].id)
# found subject to remove:  ['86972', '985910486', 'sub-985910486'] 5ec5d9cf1a0c1d11d116a106
# client.delete_subject(target[0].id)
# found subject to remove:  ['86974', '876444031', 'sub-876444031'] 5ec5dff41a0c1d124b169e02
# client.delete_subject(target[0].id)
# found subject to remove:  ['86990', '677581716', 'sub-677581716'] 5ec5e5521a0c1d1256169ef5
# client.delete_subject(target[0].id)
# found subject to remove:  ['87045', '2688141773', 'sub-2688141773'] 5ec5ef341a0c1d1242169f6e
# client.delete_subject(target[0].id)
# found subject to remove:  ['87048', '31361606', 'sub-31361606'] 5dd9a97640116e005bb53e17
# client.delete_subject(target[0].id)
# found subject to remove:  ['87053', '756380264', 'sub-756380264'] 5de7c6f340116e005bcf7d52
# client.delete_subject(target[0].id)
# found subject to remove:  ['87064', '749654008', 'sub-749654008'] 5dd9046140116e005bb4062a
# client.delete_subject(target[0].id)
# found subject to remove:  ['87122', '2490635263', 'sub-2490635263'] 5dd03a7be74aa3006036d7e3
# client.delete_subject(target[0].id)
# found subject to remove:  ['87135', '1705895007', 'sub-1705895007'] 5dea307f40116e0057bcc4ff
# client.delete_subject(target[0].id)
# found subject to remove:  ['87144', '1200684014', 'sub-1200684014'] 5dd9bdca40116e005bb563a5
# client.delete_subject(target[0].id)
# found subject to remove:  ['87166', '1310206420', 'sub-1310206420'] 5de6bd9340116e0057bc97b5
# client.delete_subject(target[0].id)
# found subject to remove:  ['87189', '78982423', 'sub-78982423'] 5de6e63140116e0058c4e32a
# client.delete_subject(target[0].id)
# found subject to remove:  ['87195', '2745152671', 'sub-2745152671'] 5dd57a2ae74aa3005e2af7b6
# client.delete_subject(target[0].id)
# found subject to remove:  ['87209', '2108841974', 'sub-2108841974'] 5dd99dcc40116e0058b4973c
# client.delete_subject(target[0].id)
# found subject to remove:  ['87277', '3666908232', 'sub-3666908232'] 5dd8cc5e40116e0058b38bc4
# client.delete_subject(target[0].id)
# found subject to remove:  ['87282', '487664430', 'sub-487664430'] 5dd9eca140116e0057b45757
# client.delete_subject(target[0].id)
# found subject to remove:  ['87300', '55710183', 'sub-55710183'] 5dd6f91be74aa3005e2cdbf5
# client.delete_subject(target[0].id)
# found subject to remove:  ['87344', '3644730316', 'sub-3644730316'] 5dd98ea140116e0058b48491
# client.delete_subject(target[0].id)
# found subject to remove:  ['87346', '550810566', 'sub-550810566'] 5dd030aee74aa3006036c43d
# client.delete_subject(target[0].id)
# found subject to remove:  ['87381', '1240942354', 'sub-1240942354'] 5dd880a2e74aa3005c19fbe3
# client.delete_subject(target[0].id)
# found subject to remove:  ['87445', '3704894948', 'sub-3704894948'] 5de97fc340116e0053b5753b
# client.delete_subject(target[0].id)
# found subject to remove:  ['87457', '2182362214', 'sub-2182362214'] 5df1e4b7d566950078c0b660
# client.delete_subject(target[0].id)
# found subject to remove:  ['87470', '612700286', 'sub-612700286'] 5df00bd0d56695005bc042a6
# client.delete_subject(target[0].id)
# found subject to remove:  ['87530', '1185574887', 'sub-1185574887'] 5dd97f7a40116e005bb4ecff
# client.delete_subject(target[0].id)
# found subject to remove:  ['87538', '1823231434', 'sub-1823231434'] 5dd465cde74aa3005c170112
# client.delete_subject(target[0].id)
# found subject to remove:  ['87548', '845422206', 'sub-845422206'] 5dd9e2e940116e0054b3e11f
# client.delete_subject(target[0].id)
# found subject to remove:  ['87563', '1830789740', 'sub-1830789740'] 5dea00e540116e0058c52483
# client.delete_subject(target[0].id)
# found subject to remove:  ['87601', '2551635949', 'sub-2551635949'] 5dd48e0ae74aa3005c171cc3
# client.delete_subject(target[0].id)
# found subject to remove:  ['87604', '335003211', 'sub-335003211'] 5deaf5f840116e005bcffedb
# client.delete_subject(target[0].id)
# found subject to remove:  ['87646', '3345297865', 'sub-3345297865'] 5dd4c709e74aa3005e2a0f90
# client.delete_subject(target[0].id)
# found subject to remove:  ['87670', '3123429468', 'sub-3123429468'] 5dd9824840116e0057b40611
# client.delete_subject(target[0].id)
# found subject to remove:  ['87679', '355612286', 'sub-355612286'] 5df20512d566950078c0ba4e
# client.delete_subject(target[0].id)
# found subject to remove:  ['87696', '1604268733', 'sub-1604268733'] 5dda09ab40116e005bb5fbe1
# client.delete_subject(target[0].id)
# found subject to remove:  ['87699', '4269306166', 'sub-4269306166'] 5de663be40116e0058c474cc
# client.delete_subject(target[0].id)
# found subject to remove:  ['87737', '2398605805', 'sub-2398605805'] 5df027e1d56695006cc060ae
# client.delete_subject(target[0].id)
# found subject to remove:  ['87772', '211169351', 'sub-211169351'] 5dd4ef3de74aa3005c175a16
# client.delete_subject(target[0].id)
# found subject to remove:  ['87804', '3032863642', 'sub-3032863642'] 5dd9dcc640116e0058b4ea6e
# client.delete_subject(target[0].id)
# found subject to remove:  ['87842', '2537779643', 'sub-2537779643'] 5dd79355e74aa3006043b420
# client.delete_subject(target[0].id)
# found subject to remove:  ['87862', '1730231179', 'sub-1730231179'] 5df16829d566950078c0a8dd
# client.delete_subject(target[0].id)
# found subject to remove:  ['87878', '924815264', 'sub-924815264'] 5dd9141b40116e0057b3b57a
# client.delete_subject(target[0].id)
# found subject to remove:  ['87905', '2271737742', 'sub-2271737742'] 5dd971c940116e005bb4d1b3
# client.delete_subject(target[0].id)
# found subject to remove:  ['87936', '1908959165', 'sub-1908959165'] 5de6dd7540116e005bcf6c87
# client.delete_subject(target[0].id)
# found subject to remove:  ['87947', '1997401992', 'sub-1997401992'] 5dd9b1fc40116e0058b4b37b
# client.delete_subject(target[0].id)
# found subject to remove:  ['87990', '3104080596', 'sub-3104080596'] 5df14ad4d566950078c0a137
# client.delete_subject(target[0].id)
# found subject to remove:  ['88013', '1781205887', 'sub-1781205887'] 5dd9a32f40116e0058b49ffd
# client.delete_subject(target[0].id)
# found subject to remove:  ['88023', '429608771', 'sub-429608771'] 5dd5a366e74aa3005e2b3099
# client.delete_subject(target[0].id)
# found subject to remove:  ['88055', '1236117854', 'sub-1236117854'] 5dd97a0c40116e005bb4df0a
# client.delete_subject(target[0].id)
# found subject to remove:  ['88075', '3117409134', 'sub-3117409134'] 5df1c871d56695006cc078a4
# client.delete_subject(target[0].id)
# found subject to remove:  ['88094', '779151395', 'sub-779151395'] 5df1e1abd566950078c0b5f1
# client.delete_subject(target[0].id)
# found subject to remove:  ['88120', '131655018', 'sub-131655018'] 5dd45c8be74aa3005c16fb98
# client.delete_subject(target[0].id)
# found subject to remove:  ['88137', '3539567950', 'sub-3539567950'] 5dd9c38a40116e005bb56e73
# client.delete_subject(target[0].id)
# found subject to remove:  ['88149', '1977306864', 'sub-1977306864'] 5dd84c69e74aa3006045195b
# client.delete_subject(target[0].id)
# found subject to remove:  ['88162', '3544869608', 'sub-3544869608'] 5dda375d40116e005bb654a4
# client.delete_subject(target[0].id)
# found subject to remove:  ['88166', '610158411', 'sub-610158411'] 5dd75b55e74aa3005a0bac80
# client.delete_subject(target[0].id)
# found subject to remove:  ['88181', '3172989359', 'sub-3172989359'] 5dd5eca9e74aa3005e2b9292
# client.delete_subject(target[0].id)
# found subject to remove:  ['88190', '1111014310', 'sub-1111014310'] 5dd9b53d40116e0058b4b7f4
# client.delete_subject(target[0].id)
# found subject to remove:  ['88209', '401879401', 'sub-401879401'] 5dd01869e74aa3005703280c
# client.delete_subject(target[0].id)
# found subject to remove:  ['88229', '3885398873', 'sub-3885398873'] 5df15293d566950059c03bfc
# client.delete_subject(target[0].id)
# found subject to remove:  ['88241', '3915422918', 'sub-3915422918'] 5dd9682440116e0057b3f1e8
# client.delete_subject(target[0].id)
# found subject to remove:  ['88283', '195168692', 'sub-195168692'] 5dd42537e74aa300603d9fce
# client.delete_subject(target[0].id)
# found subject to remove:  ['88305', '3807715038', 'sub-3807715038'] 5dd96b1640116e005bb4c34f
# client.delete_subject(target[0].id)
# found subject to remove:  ['88384', '2823833643', 'sub-2823833643'] 5de8f4fa40116e0058c508de
# client.delete_subject(target[0].id)
# found subject to remove:  ['88395', '1467419170', 'sub-1467419170'] 5dd95c7440116e005bb4a880
# client.delete_subject(target[0].id)
# found subject to remove:  ['88402', '3923883359', 'sub-3923883359'] 5dd9393f40116e0058b41371
# client.delete_subject(target[0].id)
# found subject to remove:  ['88412', '1781775187', 'sub-1781775187'] 5deb1fd740116e0058c53c59
# client.delete_subject(target[0].id)
# found subject to remove:  ['88425', '1804076739', 'sub-1804076739'] 5dd901b540116e0058b3c9dd
# client.delete_subject(target[0].id)
# found subject to remove:  ['88486', '681935372', 'sub-681935372'] 5df218bfd56695005bc05380
# client.delete_subject(target[0].id)
# found subject to remove:  ['88505', '3569165538', 'sub-3569165538'] 5deab26940116e005bcff979
# client.delete_subject(target[0].id)
# found subject to remove:  ['88541', '248585929', 'sub-248585929'] 5dd7c55de74aa3006044133f
# client.delete_subject(target[0].id)
# found subject to remove:  ['88547', '618085604', 'sub-618085604'] 5dd96e0640116e005bb4ca25
# client.delete_subject(target[0].id)
# found subject to remove:  ['88568', '2822781649', 'sub-2822781649'] 5dd8d25440116e005bb3a7ee
# client.delete_subject(target[0].id)
# found subject to remove:  ['88589', '3323308438', 'sub-3323308438'] 5dd8cf1940116e0054b38177
# client.delete_subject(target[0].id)
# found subject to remove:  ['88608', '2762202970', 'sub-2762202970'] 5dea152c40116e005bcfdc2a
# client.delete_subject(target[0].id)
# found subject to remove:  ['88618', '661770582', 'sub-661770582'] 5de9b22240116e005bcfd7f6
# client.delete_subject(target[0].id)
# found subject to remove:  ['88621', '36895554', 'sub-36895554'] 5dd9979640116e0058b490e2
# client.delete_subject(target[0].id)
# found subject to remove:  ['88672', '696727241', 'sub-696727241'] 5de9398a40116e0054b7c4a7
# client.delete_subject(target[0].id)
# found subject to remove:  ['88677', '2258551019', 'sub-2258551019'] 5dd4b2dbe74aa3005c173382
# client.delete_subject(target[0].id)
# found subject to remove:  ['88760', '485017822', 'sub-485017822'] 5df173f0d566950078c0a9c5
# client.delete_subject(target[0].id)
# found subject to remove:  ['88770', '2671429330', 'sub-2671429330'] 5dd9853540116e0051b38950
# client.delete_subject(target[0].id)
# found subject to remove:  ['88773', '438637277', 'sub-438637277'] 5df1d82ed566950078c0b4b7
# client.delete_subject(target[0].id)
# found subject to remove:  ['88844', '4093356685', 'sub-4093356685'] 5df1015bd566950078c09644
# client.delete_subject(target[0].id)
# found subject to remove:  ['88859', '673480448', 'sub-673480448'] 5df1eaacd56695006cc07afb
# client.delete_subject(target[0].id)
# found subject to remove:  ['88867', '2726208310', 'sub-2726208310'] 5dd98b3e40116e0058b480a9
# client.delete_subject(target[0].id)
# found subject to remove:  ['88869', '1536441148', 'sub-1536441148'] 5dd9420f40116e0058b41cdb
# client.delete_subject(target[0].id)
# found subject to remove:  ['88902', '2670354621', 'sub-2670354621'] 5dd532e2e74aa3005c178ca3
# client.delete_subject(target[0].id)
# found subject to remove:  ['88907', '808687263', 'sub-808687263'] 5dd513fbe74aa300603f79f7
# client.delete_subject(target[0].id)
# found subject to remove:  ['88918', '3474248854', 'sub-3474248854'] 5df1db57d566950078c0b52d
# client.delete_subject(target[0].id)
# found subject to remove:  ['89044', '138434806', 'sub-138434806'] 5de8c01840116e0053b57031
# client.delete_subject(target[0].id)
# found subject to remove:  ['89053', '4187598678', 'sub-4187598678'] 5dd9ac7040116e005bb540ac
# client.delete_subject(target[0].id)
# found subject to remove:  ['89063', '2318003050', 'sub-2318003050'] 5dd8c5e340116e0054b37e53
# client.delete_subject(target[0].id)
# found subject to remove:  ['89104', '3194237272', 'sub-3194237272'] 5dd8ac0de74aa3005c1a1ca2
# client.delete_subject(target[0].id)
# found subject to remove:  ['89115', '1094939473', 'sub-1094939473'] 5dd9881040116e0058b47baa
# client.delete_subject(target[0].id)
# found subject to remove:  ['89184', '2285120424', 'sub-2285120424'] 5dee8587d56695006cc0284d
# client.delete_subject(target[0].id)
# found subject to remove:  ['89186', '1910420386', 'sub-1910420386'] 5dea88be40116e0054b7caa8
# client.delete_subject(target[0].id)
# found subject to remove:  ['89260', '3678218578', 'sub-3678218578'] 5dd92ad940116e0057b3c4a8
# client.delete_subject(target[0].id)
# found subject to remove:  ['89279', '4160147836', 'sub-4160147836'] 5dd4de76e74aa300603f1a2f
# client.delete_subject(target[0].id)
# found subject to remove:  ['89288', '443632695', 'sub-443632695'] 5df0d924d566950078c0947b
# client.delete_subject(target[0].id)
# found subject to remove:  ['89300', '3621702873', 'sub-3621702873'] 5dd8e2da40116e005bb3c808
# client.delete_subject(target[0].id)
# found subject to remove:  ['89320', '666666729', 'sub-666666729'] 5de5ecb640116e005bcddc7c
# client.delete_subject(target[0].id)
# found subject to remove:  ['89367', '1547173705', 'sub-1547173705'] 5de7af0740116e0058c4e9e7
# client.delete_subject(target[0].id)
# found subject to remove:  ['89377', '3756388677', 'sub-3756388677'] 5de62a9040116e005bce56a2
# client.delete_subject(target[0].id)
# found subject to remove:  ['89383', '1687224870', 'sub-1687224870'] 5df20f57d566950059c04188
# client.delete_subject(target[0].id)
# found subject to remove:  ['89502', '410808047', 'sub-410808047'] 5dee920cd566950078c030ec
# client.delete_subject(target[0].id)
# found subject to remove:  ['89505', '1786222403', 'sub-1786222403'] 5de91c3f40116e0058c50dcd
# client.delete_subject(target[0].id)
# found subject to remove:  ['89525', '2585124211', 'sub-2585124211'] 5df1fab2d56695006cc07c20
# client.delete_subject(target[0].id)
# found subject to remove:  ['89534', '1697816442', 'sub-1697816442'] 5df1b0d3d56695006cc076aa
# client.delete_subject(target[0].id)
# found subject to remove:  ['89557', '433029449', 'sub-433029449'] 5dd9477840116e005bb47f38
# client.delete_subject(target[0].id)
# found subject to remove:  ['89561', '1081730904', 'sub-1081730904'] 5def08ead56695006cc04cb7
# client.delete_subject(target[0].id)
# found subject to remove:  ['89567', '1786758517', 'sub-1786758517'] 5dd0111de74aa3005c13b719
# client.delete_subject(target[0].id)
# found subject to remove:  ['89627', '2533255886', 'sub-2533255886'] 5de8c2b040116e0057bcb069
# client.delete_subject(target[0].id)
# found subject to remove:  ['89653', '467305309', 'sub-467305309'] 5dd8f9a340116e005bb3f525
# client.delete_subject(target[0].id)
# found subject to remove:  ['89716', '4061437282', 'sub-4061437282'] 5dd95f4940116e005bb4acee
# client.delete_subject(target[0].id)
# found subject to remove:  ['89731', '1887252222', 'sub-1887252222'] 5de97d0d40116e005bcfd50b
# client.delete_subject(target[0].id)
# found subject to remove:  ['89786', '1201047966', 'sub-1201047966'] 5dd919fa40116e0057b3b9f6
# client.delete_subject(target[0].id)
# found subject to remove:  ['89816', '443652258', 'sub-443652258'] 5dd8ebe940116e0057b39c23
# client.delete_subject(target[0].id)
# found subject to remove:  ['89834', '335104664', 'sub-335104664'] 5dd9336a40116e005bb45562
# client.delete_subject(target[0].id)
# found subject to remove:  ['89878', '3818082974', 'sub-3818082974'] 5df0f572d56695005bc0465e
# client.delete_subject(target[0].id)
# found subject to remove:  ['89881', '3724047858', 'sub-3724047858'] 5df09c43d566950057c02d3c
# client.delete_subject(target[0].id)
# found subject to remove:  ['90021', '2051099070', 'sub-2051099070'] 5dd074cfe74aa30060374415
# client.delete_subject(target[0].id)
# found subject to remove:  ['90042', '574930953', 'sub-574930953'] 5df1a182d56695005bc04eca
# client.delete_subject(target[0].id)
# found subject to remove:  ['90050', '1484543503', 'sub-1484543503'] 5de9c2b240116e0053b57570
# client.delete_subject(target[0].id)
# found subject to remove:  ['90060', '734794291', 'sub-734794291'] 5dea54b140116e0058c52663
# client.delete_subject(target[0].id)
# found subject to remove:  ['90066', '624076698', 'sub-624076698'] 5de5660540116e0054b73b1b
# client.delete_subject(target[0].id)
# found subject to remove:  ['90077', '4276974103', 'sub-4276974103'] 5dd8d1c340116e005bb3a5f9
# client.delete_subject(target[0].id)
# found subject to remove:  ['90113', '1799875502', 'sub-1799875502'] 5df1de75d566950078c0b582
# client.delete_subject(target[0].id)
# found subject to remove:  ['90116', '3769010696', 'sub-3769010696'] 5de53bd640116e0058c2efb2
# client.delete_subject(target[0].id)
# found subject to remove:  ['90211', '3724155829', 'sub-3724155829'] 5de9c01240116e005bcfd89e
# client.delete_subject(target[0].id)
# found subject to remove:  ['90217', '4160502168', 'sub-4160502168'] 5dd8fee240116e0057b3a7b0
# client.delete_subject(target[0].id)
# found subject to remove:  ['90241', '1934623281', 'sub-1934623281'] 5dd906fb40116e0058b3cf6c
# client.delete_subject(target[0].id)
# found subject to remove:  ['90262', '103652366', 'sub-103652366'] 5df176f4d566950078c0a9e7
# client.delete_subject(target[0].id)
# found subject to remove:  ['90281', '1752698697', 'sub-1752698697'] 5de9bd5540116e005bcfd879
# client.delete_subject(target[0].id)
# found subject to remove:  ['90367', '2026754591', 'sub-2026754591'] 5dd8272ce74aa3006044d352
# ...
# client.delete_subject(target[0].id)
# found subject to remove:  ['129926', '2972126748', 'sub-2972126748'] 5dd78ae6e74aa3005c194ae4
# client.delete_subject(target[0].id)
# found subject to remove:  ['129965', '3439727076', 'sub-3439727076'] 5dd6c3d3e74aa30053ff5d16
# client.delete_subject(target[0].id)
# found subject to remove:  ['130034', '867458668', 'sub-867458668'] 5de5806940116e0057bbc971
# client.delete_subject(target[0].id)
# found subject to remove:  ['130067', '634597131', 'sub-634597131'] 5dd866dfe74aa3005c19e841
# client.delete_subject(target[0].id)
# found subject to remove:  ['130088', '915920148', 'sub-915920148'] 5dd87811e74aa300604564bb
# client.delete_subject(target[0].id)
# found subject to remove:  ['130106', '194324018', 'sub-194324018'] 5dcfffd9e74aa30060366974
# client.delete_subject(target[0].id)
# found subject to remove:  ['130121', '2785454369', 'sub-2785454369'] 5dd7b903e74aa3006043face
# client.delete_subject(target[0].id)
# found subject to remove:  ['130151', '3038035275', 'sub-3038035275'] 5dd615c8e74aa3005c183249
# client.delete_subject(target[0].id)
# found subject to remove:  ['130154', '1386561348', 'sub-1386561348'] 5dd6e11ce74aa3005e2cc5c7
# client.delete_subject(target[0].id)
# found subject to remove:  ['130178', '1150591062', 'sub-1150591062'] 5dd8884fe74aa3004ffe5b67
# client.delete_subject(target[0].id)
# found subject to remove:  ['130199', '3746502009', 'sub-3746502009'] 5dd6ecfde74aa3005a0b7de4
# client.delete_subject(target[0].id)
# found subject to remove:  ['130211', '2613113832', 'sub-2613113832'] 5dd80ec2e74aa30051febcb1
# client.delete_subject(target[0].id)
# found subject to remove:  ['130250', '2906925573', 'sub-2906925573'] 5dd609e6e74aa3005e2bb7ce
# client.delete_subject(target[0].id)
# found subject to remove:  ['130332', '408837402', 'sub-408837402'] 5dd8758ee74aa3006045609a
# client.delete_subject(target[0].id)
# found subject to remove:  ['130346', '1023701836', 'sub-1023701836'] 5dd4d7bbe74aa300603f0d20
# client.delete_subject(target[0].id)
# found subject to remove:  ['130405', '1197045954', 'sub-1197045954'] 5dd7ccd1e74aa3005e2dc073
# client.delete_subject(target[0].id)
# found subject to remove:  ['130411', '2247752771', 'sub-2247752771'] 5dd81579e74aa3006044af3b
# client.delete_subject(target[0].id)
# found subject to remove:  ['130438', '2404916865', 'sub-2404916865'] 5dcf844ce74aa3005e23cfa6
# client.delete_subject(target[0].id)
# found subject to remove:  ['130480', '4137052624', 'sub-4137052624'] 5dd7b000e74aa3006043eaf0
# client.delete_subject(target[0].id)
# found subject to remove:  ['130615', '3059148008', 'sub-3059148008'] 5dd8642ce74aa3005c19e598
# client.delete_subject(target[0].id)
# found subject to remove:  ['130618', '3231527178', 'sub-3231527178'] 5dd81e72e74aa3006044bf17
# client.delete_subject(target[0].id)
# found subject to remove:  ['130639', '1531348005', 'sub-1531348005'] 5dd82abfe74aa3006044da68
# client.delete_subject(target[0].id)
# found subject to remove:  ['130687', '3234586495', 'sub-3234586495'] 5dd800afe74aa3005a0be44f
# client.delete_subject(target[0].id)
# found subject to remove:  ['130693', '3605497536', 'sub-3605497536'] 5dd7e17ee74aa3005c1987ee
# client.delete_subject(target[0].id)
# found subject to remove:  ['130759', '978838797', 'sub-978838797'] 5dd7dbe1e74aa30060443cf0
# client.delete_subject(target[0].id)
# found subject to remove:  ['130845', '1779531630', 'sub-1779531630'] 5dd818aee74aa3006044b712
# client.delete_subject(target[0].id)
# found subject to remove:  ['130858', '1989985299', 'sub-1989985299'] 5dd86fa7e74aa3006045548d
# client.delete_subject(target[0].id)
# found subject to remove:  ['130859', '969649154', 'sub-969649154'] 5dd872b4e74aa3005e2e7c03
# client.delete_subject(target[0].id)
# found subject to remove:  ['130861', '377178190', 'sub-377178190'] 5dd84637e74aa3005a0c036a
# client.delete_subject(target[0].id)
# found subject to remove:  ['130863', '2295699564', 'sub-2295699564'] 5dd64876e74aa3006041b8bf
# client.delete_subject(target[0].id)
# found subject to remove:  ['130881', '3982145425', 'sub-3982145425'] 5dd7ace4e74aa3005c196421
# client.delete_subject(target[0].id)
# found subject to remove:  ['130896', '714036765', 'sub-714036765'] 5dd6190be74aa3005e2bc82f
# client.delete_subject(target[0].id)
# found subject to remove:  ['130908', '2840008346', 'sub-2840008346'] 5dd6837ee74aa3005500a2ec
# client.delete_subject(target[0].id)
# found subject to remove:  ['131010', '2905849066', 'sub-2905849066'] 5dd82447e74aa3006044cd1c
# client.delete_subject(target[0].id)
# found subject to remove:  ['131076', '3439662539', 'sub-3439662539'] 5dd61ce9e74aa3005c183629
# client.delete_subject(target[0].id)
# found subject to remove:  ['131082', '2433433960', 'sub-2433433960'] 5dd7880fe74aa3005c1948e0
# client.delete_subject(target[0].id)
# found subject to remove:  ['131085', '1991951207', 'sub-1991951207'] 5dd716fee74aa3006042cf61
# client.delete_subject(target[0].id)
# found subject to remove:  ['131160', '2791617373', 'sub-2791617373'] 5dd62be8e74aa3005a0b2d66
# client.delete_subject(target[0].id)
# found subject to remove:  ['131172', '3808965674', 'sub-3808965674'] 5dd7f20ae74aa3005a0bdf0c
# client.delete_subject(target[0].id)
# found subject to remove:  ['131220', '2293300734', 'sub-2293300734'] 5dd79daae74aa3005c19598a
# client.delete_subject(target[0].id)
# found subject to remove:  ['131224', '4099736023', 'sub-4099736023'] 5dcfe742e74aa30060363aa3
# client.delete_subject(target[0].id)
# found subject to remove:  ['131251', '16684978', 'sub-16684978'] 5de57d9b40116e0051b44620
# client.delete_subject(target[0].id)
# found subject to remove:  ['131306', '2788824854', 'sub-2788824854'] 5dd71053e74aa3005a0b8a0c
# client.delete_subject(target[0].id)
# found subject to remove:  ['131405', '1908390739', 'sub-1908390739'] 5dd67d8ce74aa30060421710
# client.delete_subject(target[0].id)
# found subject to remove:  ['131444', '2469426313', 'sub-2469426313'] 5dd5efe7e74aa30060411200
# client.delete_subject(target[0].id)
# found subject to remove:  ['131447', '1120521402', 'sub-1120521402'] 5dd69ddee74aa3005e2c66a0
# client.delete_subject(target[0].id)
# found subject to remove:  ['131474', '3604691191', 'sub-3604691191'] 5dd6592de74aa3005e2c1405
# client.delete_subject(target[0].id)
# found subject to remove:  ['131534', '2556918590', 'sub-2556918590'] 5dd60d15e74aa30060414505
# client.delete_subject(target[0].id)
# found subject to remove:  ['131543', '4067048825', 'sub-4067048825'] 5dd6b108e74aa3005c1897c4
# client.delete_subject(target[0].id)
# found subject to remove:  ['131552', '1238756309', 'sub-1238756309'] 5dd7793be74aa30057049578
# client.delete_subject(target[0].id)
# found subject to remove:  ['131561', '3091738725', 'sub-3091738725'] 5dcfb141e74aa3006035d2b2
# client.delete_subject(target[0].id)
# found subject to remove:  ['131603', '3703469018', 'sub-3703469018'] 5dd56aaae74aa3005e2ae352
# client.delete_subject(target[0].id)
# found subject to remove:  ['131622', '3653965527', 'sub-3653965527'] 5dd84245e74aa3005c19d85d
# client.delete_subject(target[0].id)
# found subject to remove:  ['131635', '1413282375', 'sub-1413282375'] 5dd7e6abe74aa3005c198bbd
# client.delete_subject(target[0].id)
# found subject to remove:  ['131651', '2240703148', 'sub-2240703148'] 5dd6887fe74aa30060422cd8
# client.delete_subject(target[0].id)
# found subject to remove:  ['131657', '3016118416', 'sub-3016118416'] 5dd74eaee74aa300604337fb
# client.delete_subject(target[0].id)
# found subject to remove:  ['131666', '1113295648', 'sub-1113295648'] 5dd57052e74aa3005e2ae94c
# client.delete_subject(target[0].id)
# found subject to remove:  ['131702', '352505908', 'sub-352505908'] 5dd81b65e74aa3005e2e2041
# client.delete_subject(target[0].id)
# found subject to remove:  ['131729', '530789110', 'sub-530789110'] 5dd7cf22e74aa30060442615
# client.delete_subject(target[0].id)
# found subject to remove:  ['131738', '984757368', 'sub-984757368'] 5dd7059ae74aa3006042a9c3
# client.delete_subject(target[0].id)
# found subject to remove:  ['131747', '3250922962', 'sub-3250922962'] 5dcffc6fe74aa300603662d2
# client.delete_subject(target[0].id)
# found subject to remove:  ['131798', '3100094802', 'sub-3100094802'] 5dd740fbe74aa30060431f1d
# client.delete_subject(target[0].id)
# found subject to remove:  ['131810', '2832458131', 'sub-2832458131'] 5dd625d1e74aa3005e2bd9e4
# client.delete_subject(target[0].id)
# found subject to remove:  ['131819', '2734016600', 'sub-2734016600'] 5dd79a4fe74aa30057049af0
# client.delete_subject(target[0].id)
# found subject to remove:  ['131837', '3511384247', 'sub-3511384247'] 5dd5fa08e74aa3005e2ba376
# client.delete_subject(target[0].id)
# found subject to remove:  ['131867', '383103459', 'sub-383103459'] 5dd805b2e74aa30060448fa7
# client.delete_subject(target[0].id)
# found subject to remove:  ['131927', '2739408373', 'sub-2739408373'] 5dd52721e74aa3005e2a87a5
# client.delete_subject(target[0].id)
# found subject to remove:  ['131951', '2249335715', 'sub-2249335715'] 5dcf7ea3e74aa30060356969
# client.delete_subject(target[0].id)
# found subject to remove:  ['131993', '3818720350', 'sub-3818720350'] 5dd7087be74aa3006042b232
# client.delete_subject(target[0].id)
# found subject to remove:  ['132059', '4083266820', 'sub-4083266820'] 5dd75196e74aa30060433e79
# client.delete_subject(target[0].id)
# found subject to remove:  ['132071', '1303822344', 'sub-1303822344'] 5dd6f019e74aa3006042838f
# client.delete_subject(target[0].id)
# found subject to remove:  ['132083', '3109977781', 'sub-3109977781'] 5dd670f6e74aa3005a0b4179
# client.delete_subject(target[0].id)
# found subject to remove:  ['132086', '1592786106', 'sub-1592786106'] 5dd590c6e74aa3005c17d323
# client.delete_subject(target[0].id)
# found subject to remove:  ['132097', '2943493898', 'sub-2943493898'] 5dd790a7e74aa3005e2d7b44
# client.delete_subject(target[0].id)
# found subject to remove:  ['132111', '3615907583', 'sub-3615907583'] 5dd529f2e74aa3005c178528
# client.delete_subject(target[0].id)
# found subject to remove:  ['132130', '2555837927', 'sub-2555837927'] 5dd72c4be74aa3005e2d02d0
# client.delete_subject(target[0].id)
# found subject to remove:  ['132179', '3297348664', 'sub-3297348664'] 5dd6f639e74aa30060428e42
# client.delete_subject(target[0].id)
# found subject to remove:  ['132209', '2947976933', 'sub-2947976933'] 5dd6d7b0e74aa3004dfe15e1
# client.delete_subject(target[0].id)
# found subject to remove:  ['132224', '233932345', 'sub-233932345'] 5dd6f307e74aa300604288ba
# client.delete_subject(target[0].id)
# found subject to remove:  ['132296', '2070724014', 'sub-2070724014'] 5dd63220e74aa30060418992
# client.delete_subject(target[0].id)
# found subject to remove:  ['132431', '2654954754', 'sub-2654954754'] 5dd641e7e74aa3006041abaa
# client.delete_subject(target[0].id)
# found subject to remove:  ['132470', '1402618672', 'sub-1402618672'] 5dd697fbe74aa3005e2c5f04
# client.delete_subject(target[0].id)
# found subject to remove:  ['132554', '413107749', 'sub-413107749'] 5dd6d120e74aa3005500ae03
# client.delete_subject(target[0].id)
# found subject to remove:  ['132560', '3669543341', 'sub-3669543341'] 5dd6c075e74aa3005c18a7a5
# client.delete_subject(target[0].id)
# found subject to remove:  ['132566', '956032422', 'sub-956032422'] 5dd66b1fe74aa3006041fa70
# client.delete_subject(target[0].id)
# found subject to remove:  ['132605', '324718088', 'sub-324718088'] 5dd68f0ce74aa3005500a3ed
# client.delete_subject(target[0].id)
# found subject to remove:  ['132641', '375686109', 'sub-375686109'] 5dd6a411e74aa3005c188c45
# client.delete_subject(target[0].id)
# found subject to remove:  ['132657', '1248515966', 'sub-1248515966'] 5dd68bc6e74aa30060423114
# client.delete_subject(target[0].id)
# found subject to remove:  ['132658', '2718945982', 'sub-2718945982'] 5dd6d50de74aa30053ff633a
# client.delete_subject(target[0].id)
# found subject to remove:  ['132782', '1859900144', 'sub-1859900144'] 5dd622e1e74aa3005c183a60
# client.delete_subject(target[0].id)
# found subject to remove:  ['132785', '2305446143', 'sub-2305446143'] 5dd52cf8e74aa3005e2a9420
# client.delete_subject(target[0].id)
# found subject to remove:  ['132788', '4288775453', 'sub-4288775453'] 5dd6c76ae74aa30051fea7de
# client.delete_subject(target[0].id)
# found subject to remove:  ['132791', '2672167232', 'sub-2672167232'] 5dd6955de74aa3005c188025
# client.delete_subject(target[0].id)
# found subject to remove:  ['132905', '281446151', 'sub-281446151'] 5dd713bfe74aa3005a0b8bc2
# client.delete_subject(target[0].id)
# found subject to remove:  ['132995', '746172812', 'sub-746172812'] 5dd6de31e74aa3005e2cc144
# client.delete_subject(target[0].id)
# found subject to remove:  ['133007', '2650375172', 'sub-2650375172'] 5dd72f21e74aa3006042fd86
# client.delete_subject(target[0].id)
# found subject to remove:  ['133145', '3066751024', 'sub-3066751024'] 5dd5ba56e74aa3005a0b080a
# client.delete_subject(target[0].id)
# found subject to remove:  ['133220', '2133389205', 'sub-2133389205'] 5dd535e0e74aa300603fa661
# client.delete_subject(target[0].id)
# found subject to remove:  ['133228', '978955855', 'sub-978955855'] 5dd6cdbce74aa3004dfe102d
# client.delete_subject(target[0].id)
# found subject to remove:  ['133240', '108828000', 'sub-108828000'] 5dd53efee74aa300603fb52d
# client.delete_subject(target[0].id)
# found subject to remove:  ['133242', '3531047767', 'sub-3531047767'] 5dd68620e74aa3006042260a
# client.delete_subject(target[0].id)
# found subject to remove:  ['135130', '3370689672', 'sub-3370689672'] 5dcf8168e74aa30060356fc9
# client.delete_subject(target[0].id)
# found subject to remove:  ['135484', '361728233', 'sub-361728233'] 5dcf67fce74aa3005e23afc9
# client.delete_subject(target[0].id)
# found subject to remove:  ['136004', '482239832', 'sub-482239832'] 5dd0030de74aa30060366f70
# client.delete_subject(target[0].id)
# found subject to remove:  ['138587', '3463353736', 'sub-3463353736'] 5dcf61cfe74aa300603533f2
# client.delete_subject(target[0].id)
# found subject to remove:  ['138788', '3175244541', 'sub-3175244541'] 5dcf7893e74aa3005703134a
# client.delete_subject(target[0].id)
# found subject to remove:  ['138875', '2723385487', 'sub-2723385487'] 5dcf3026e74aa300570306c8
# client.delete_subject(target[0].id)
# found subject to remove:  ['138908', '619623685', 'sub-619623685'] 5dc46ccce74aa300601ab1c2
# client.delete_subject(target[0].id)
# found subject to remove:  ['138923', '2967570405', 'sub-2967570405'] 5dcf9d07e74aa3006035a7aa
# client.delete_subject(target[0].id)
# found subject to remove:  ['138929', '3207921706', 'sub-3207921706'] 5dcf3325e74aa3005e237349
# client.delete_subject(target[0].id)
# found subject to remove:  ['138986', '27876862', 'sub-27876862'] 5dcf5533e74aa30060351c7d
# client.delete_subject(target[0].id)
# found subject to remove:  ['139100', '2647862856', 'sub-2647862856'] 5dc464f4e74aa3005e10e21f
# client.delete_subject(target[0].id)
# found subject to remove:  ['139151', '3239156026', 'sub-3239156026'] 5dcf26f5e74aa3006034d746
# client.delete_subject(target[0].id)
# found subject to remove:  ['139181', '2231031108', 'sub-2231031108'] 5dc45e8fe74aa3005a031497
# client.delete_subject(target[0].id)
# found subject to remove:  ['139272', '585579170', 'sub-585579170'] 5dc47385e74aa300601abf0f
# client.delete_subject(target[0].id)
# found subject to remove:  ['139427', '2038321583', 'sub-2038321583'] 5dcf5b6be74aa3005c133fe6
# client.delete_subject(target[0].id)
# found subject to remove:  ['139430', '3190586154', 'sub-3190586154'] 5dcf4be3e74aa3005e238f85
# client.delete_subject(target[0].id)
# found subject to remove:  ['139469', '1939119029', 'sub-1939119029'] 5dc47715e74aa3005e10f7e6
# client.delete_subject(target[0].id)
# found subject to remove:  ['139490', '1012530688', 'sub-1012530688'] 5dc4699ae74aa300601aac20
# client.delete_subject(target[0].id)
# found subject to remove:  ['139496', '3726299659', 'sub-3726299659'] 5dcf6ab8e74aa300603546fa
# client.delete_subject(target[0].id)
# found subject to remove:  ['139532', '1919055552', 'sub-1919055552'] 5dcf64f8e74aa3005e23abed
# client.delete_subject(target[0].id)
# found subject to remove:  ['139538', '3810009389', 'sub-3810009389'] 5dcf4eb7e74aa30057030d1a
# client.delete_subject(target[0].id)
# found subject to remove:  ['139553', '3671045126', 'sub-3671045126'] 5dcf48cbe74aa3005e238c1c
# client.delete_subject(target[0].id)

# %%
penn_ids['process'] = penn_ids.apply(remove_current_rbc_subject, axis = 1)

# %%
penn_ids.to_csv('/storage/ttapera/RBC/data/bblids_2.csv', index=False)

# %%
sessions = None
#downloads = export.gather_bids(client, PNC_CS_proj.label, '80010', sessions)

# %%
sessions = None

for index, row in tqdm(penn_ids.iterrows(), total=penn_ids.shape[0]):
    
    print("Processing...")
    should_replace = False
    # first remove the existing data on RBC
    should_replace = remove_current_rbc_subject(row, RBC_subjects)
    
    if should_replace:
        # download the data from PNC
        print("Gathering PNC CS BIDS...")
        pnc1_data = export.gather_bids(client, PNC_CS_proj.label, row['bblid'], sessions)        
        print("\nDownloading BIDS...\n")
        export.download_bids(
            client, pnc1_data, 
            '/storage/ttapera/RBC/data/', 
            folders_to_download = ['anat', 'func', 'fmap'],
            dry_run=False,
            name='PNC1')

        print("Gathering PNC LG BIDS...")
        try:
            pnc2_data = export.gather_bids(client, PNC_LG_proj.label, row['bblid'], sessions)

            export.download_bids(
                client, pnc2_data, 
                '/storage/ttapera/RBC/data/', 
                folders_to_download = ['anat', 'func', 'fmap'],
                dry_run=False,
                name='PNC2')
        except:
            print("no second session!")
        
        # merge any and all data
        print("n\Merging\n")
        os.system("cp -r -R /storage/ttapera/RBC/data/PNC*/* /storage/ttapera/RBC/data/upload/")
        
        # rename the files:
        print("\nRenaming\n")
        for root, subdirs, files in os.walk("/storage/ttapera/RBC/data/upload/"):

            for f in files:
                if row['bblid'] in f:
                    print("renaming file ", f)
                    new_name = f.replace(row['bblid'], row['reid'])
                    os.rename(root + "/" + f, root + "/" + new_name)

        # rename the subject-level directory
        old_name = "/storage/ttapera/RBC/data/upload/sub-" + row['bblid']
        new_name = old_name.replace(row['bblid'], row['reid'])
        shutil.move(old_name, new_name)        
        os.system("rm -rf /storage/ttapera/RBC/data/upload/sub*/sub*")
        
        # apply defacing here
        print("\nDefacing\n")
        for root, subdirs, files in os.walk("/storage/ttapera/RBC/data/upload/"):

            for f in files:
                if ".nii" in f:
                    print("defacing " + f)
                    cmd = ("docker run -ti --rm "
                           "-v {}:/data "
                           "pennbbl/mrideface "
                           "/data/{} "
                           "/opt/mrideface/talairach_mixed_with_skull.gca "
                           "/opt/mrideface/face.gca "
                           "/data/{} ".format(root, f, f))
                    
                    print(cmd)
                    output = subprocess.check_output(cmd)
        
        # upload here
        print("\nUploading\n")
        
        # remove from filesystem here
        print("\nClearing local data\n")
        os.system("rm -rf /storage/ttapera/RBC/data/upload/*")
        os.system("rm -rf /storage/ttapera/RBC/data/PNC*")
        os.system("rm -rf /storage/ttapera/RBC/data/sub*")

# %%
check_download(path)
# Out:
# Checking for successful download in  /storage/ttapera/RBC/data/test/sub-*/ses-*/*/*.nii.gz
# /storage/ttapera/RBC/data/test/sub-80010/ses-PNC2/func/sub-80010_ses-PNC2_task-frac2back.nii.gz
# /storage/ttapera/RBC/data/test/sub-80010/ses-PNC2/func/sub-80010_ses-PNC2_task-idemo.nii.gz
# /storage/ttapera/RBC/data/test/sub-80010/ses-PNC2/func/sub-80010_ses-PNC2_task-rest_acq-singleband_bold.nii.gz
# /storage/ttapera/RBC/data/test/sub-80010/ses-PNC2/fmap/sub-80010_ses-PNC2_phase1.nii.gz
# /storage/ttapera/RBC/data/test/sub-80010/ses-PNC2/fmap/sub-80010_ses-PNC2_magnitude1.nii.gz
# /storage/ttapera/RBC/data/test/sub-80010/ses-PNC2/fmap/sub-80010_ses-PNC2_magnitude2.nii.gz
# /storage/ttapera/RBC/data/test/sub-80010/ses-PNC2/fmap/sub-80010_ses-PNC2_phase2.nii.gz
# True

# %%
def download_bids2(args):

    print("Gathering PNC CS BIDS...")

    processes = []
    
    processes.append("fw export bids /storage/ttapera/RBC/data/bids_dataset --project PNC_CS_810336 --subject {} --data-type anat".format(str(args[1])))
    
    processes.append("fw export bids /storage/ttapera/RBC/data/bids_dataset --project PNC_CS_810336 --subject {} --data-type func".format(str(args[1])))
    
    processes.append("fw export bids /storage/ttapera/RBC/data/bids_dataset --project PNC_CS_810336 --subject {} --data-type fmap".format(str(args[1])))
    
    
    processes.append("fw export bids /storage/ttapera/RBC/data/bids_dataset --project PNC_LG_810336 --subject {} --data-type anat".format(str(args[1])))
    
    processes.append("fw export bids /storage/ttapera/RBC/data/bids_dataset --project PNC_LG_810336 --subject {} --data-type func".format(str(args[1])))
    
    processes.append("fw export bids /storage/ttapera/RBC/data/bids_dataset --project PNC_LG_810336 --subject {} --data-type fmap".format(str(args[1])))

    statuses = []
    
    for process in processes:
        p = subprocess.Popen(process, shell=True)
        statuses.append(p)

    for i, p in enumerate(statuses):
        stat = p.wait()
        print("Process ", i, " complete with status ", stat)

# %%
args = ['foo', '80010', 'foofie']

# %%
def check_download(path):

    print("Checking for successful download in ", path)
    
    paths = glob.glob(path)
    paths = paths[1:]
    if len(paths) <= 1:
        return False
    for name in paths:

        print(name)
        try:
            img = nb.load(name)
        except Exception as e:
            print(e)
            return False

    return True

# %%
download_bids2(args)
# Out:
# Gathering PNC CS BIDS...
# Process  0  complete with status  0
# Process  1  complete with status  0
# Process  2  complete with status  0
# Process  3  complete with status  0
# Process  4  complete with status  0
# Process  5  complete with status  0

# %%
def cleanup_bids(path):
    
    paths = glob.glob(path)
    paths = paths[1:]

    for name in paths:

        print(name)
        pattern = re.compile("sub-[0-9]+_ses-PNC[^1]+_task-[^(rest)]")
        if pattern.search(name):
            print("removing file...")
            os.system("rm {}".format(name))

# %%
def rename_bids(args):
    
    for root, subdirs, files in os.walk("/storage/ttapera/RBC/data/bids_dataset/"):

        for f in files:
            if args[1] in f:
                print("renaming file ", f)
                new_name = f.replace(args[1], args[2])
                os.rename(root + "/" + f, root + "/" + new_name)
    
    old_name = "/storage/ttapera/RBC/data/bids_dataset/sub-" + args[1]
    new_name = old_name.replace(args[1], args[2])
    shutil.move(old_name, new_name)

# %%
rename_bids(args)

# %%
def download_bids2(args):
    
    # use the fw export bids cli + subprocess to download the anat fmap and func folders
    print("Gathering PNC BIDS...")

    processes = []
    
    processes.append("fw export bids /storage/ttapera/RBC/data/bids_dataset --project PNC_CS_810336 --subject {} --data-type anat".format(str(args[1])))
    
    processes.append("fw export bids /storage/ttapera/RBC/data/bids_dataset --project PNC_CS_810336 --subject {} --data-type func".format(str(args[1])))
    
    processes.append("fw export bids /storage/ttapera/RBC/data/bids_dataset --project PNC_CS_810336 --subject {} --data-type fmap".format(str(args[1])))
    
#    processes.append("fw export bids /storage/ttapera/RBC/data/bids_dataset --project PNC_CS_810336 --subject {} --data-type dwi".format(str(args[1])))
    
#    processes.append("fw export bids /storage/ttapera/RBC/data/bids_dataset --project PNC_LG_810336 --subject {} --data-type anat".format(str(args[1])))
    
#    processes.append("fw export bids /storage/ttapera/RBC/data/bids_dataset --project PNC_LG_810336 --subject {} --data-type func".format(str(args[1])))
    
#    processes.append("fw export bids /storage/ttapera/RBC/data/bids_dataset --project PNC_LG_810336 --subject {} --data-type fmap".format(str(args[1])))

    # use subprocess just to see which download successfully; those without PNC_LG will fail with exit 1
    statuses = []
    
    for process in processes:
        p = subprocess.Popen(process, shell=True)
        statuses.append(p)

    for i, p in enumerate(statuses):
        stat = p.wait()
        if stat == 1:
            print("Failed export:\n", processes[i])
        else:
            print("Process ", i, " complete with status ", stat)
        
def cleanup_bids(path):
    
    # Remove any files from PNC2/3 that are not 
    paths = glob.glob(path)
    paths = paths[1:]

    for name in paths:

        print(name)
        pattern = re.compile("sub-[0-9]+_ses-PNC[^1]+_task-[^(rest)]")
        if pattern.search(name):
            print("removing file...")
            os.system("rm {}".format(name))

def rename_bids(args):
    
    for root, subdirs, files in os.walk("/storage/ttapera/RBC/data/bids_dataset/"):

        for f in files:
            if args[1] in f:
                print("renaming file ", f)
                new_name = f.replace(args[1], args[2])
                os.rename(root + "/" + f, root + "/" + new_name)
    
    old_name = "/storage/ttapera/RBC/data/bids_dataset/sub-" + args[1]
    new_name = old_name.replace(args[1], args[2])
    shutil.move(old_name, new_name)

def check_headers(path):

    print("Checking for successful download in ", path)
    
    paths = glob.glob(path)
    paths = paths[1:]
    if len(paths) <= 1:
        return False
    for name in paths:
        if any([x in name for x in [".json", ".bvec", ".bval"]]):
            continue
        print(name)
        try:
            img = nb.load(name)
        except Exception as e:
            print(e)
            return False

    return True

args = ['foo', '80010', 'foofie', 'sub-foofie']
path = "/storage/ttapera/RBC/data/bids_dataset/sub-*/ses-*/*/*"

download_bids2(args)
cleanup_bids(path)
rename_bids(args)
check = check_headers(path)
print(check)
# Out:
# Gathering PNC BIDS...
# Process  0  complete with status  0
# Process  1  complete with status  0
# Process  2  complete with status  0
# Process  3  complete with status  0
# Process  4  complete with status  0
# Process  5  complete with status  0
# Process  6  complete with status  0
# /storage/ttapera/RBC/data/bids_dataset/sub-80010/ses-PNC1/anat/sub-80010_ses-PNC1_T1w.json
# /storage/ttapera/RBC/data/bids_dataset/sub-80010/ses-PNC1/func/sub-80010_ses-PNC1_task-rest_acq-singleband_bold.json
# /storage/ttapera/RBC/data/bids_dataset/sub-80010/ses-PNC1/func/sub-80010_ses-PNC1_task-rest_acq-singleband_bold.nii.gz
# /storage/ttapera/RBC/data/bids_dataset/sub-80010/ses-PNC1/dwi/sub-80010_ses-PNC1_run-02_dwi.bval
# /storage/ttapera/RBC/data/bids_dataset/sub-80010/ses-PNC1/dwi/sub-80010_ses-PNC1_run-01_dwi.nii.gz
# /storage/ttapera/RBC/data/bids_dataset/sub-80010/ses-PNC1/dwi/sub-80010_ses-PNC1_run-02_dwi.nii.gz
# /storage/ttapera/RBC/data/bids_dataset/sub-80010/ses-PNC1/dwi/sub-80010_ses-PNC1_run-02_dwi.bvec
# /storage/ttapera/RBC/data/bids_dataset/sub-80010/ses-PNC1/dwi/sub-80010_ses-PNC1_run-01_dwi.bval
# /storage/ttapera/RBC/data/bids_dataset/sub-80010/ses-PNC1/dwi/sub-80010_ses-PNC1_run-02_dwi.json
# /storage/ttapera/RBC/data/bids_dataset/sub-80010/ses-PNC1/dwi/sub-80010_ses-PNC1_run-01_dwi.json
# /storage/ttapera/RBC/data/bids_dataset/sub-80010/ses-PNC1/dwi/sub-80010_ses-PNC1_run-01_dwi.bvec
# /storage/ttapera/RBC/data/bids_dataset/sub-80010/ses-PNC2/anat/sub-80010_ses-PNC2_T1w.json
# /storage/ttapera/RBC/data/bids_dataset/sub-80010/ses-PNC2/anat/sub-80010_ses-PNC2_T1w.nii.gz
# /storage/ttapera/RBC/data/bids_dataset/sub-80010/ses-PNC2/func/sub-80010_ses-PNC2_task-frac2back.nii.gz
# removing file...
# /storage/ttapera/RBC/data/bids_dataset/sub-80010/ses-PNC2/func/sub-80010_ses-PNC2_task-idemo.json
# removing file...
# /storage/ttapera/RBC/data/bids_dataset/sub-80010/ses-PNC2/func/sub-80010_ses-PNC2_task-rest_acq-singleband_bold.json
# /storage/ttapera/RBC/data/bids_dataset/sub-80010/ses-PNC2/func/sub-80010_ses-PNC2_task-frac2back.json
# removing file...
# /storage/ttapera/RBC/data/bids_dataset/sub-80010/ses-PNC2/func/sub-80010_ses-PNC2_task-idemo.nii.gz
# removing file...
# /storage/ttapera/RBC/data/bids_dataset/sub-80010/ses-PNC2/func/sub-80010_ses-PNC2_task-rest_acq-singleband_bold.nii.gz
# /storage/ttapera/RBC/data/bids_dataset/sub-80010/ses-PNC2/fmap/sub-80010_ses-PNC2_phase1.nii.gz
# /storage/ttapera/RBC/data/bids_dataset/sub-80010/ses-PNC2/fmap/sub-80010_ses-PNC2_phase1.json
# /storage/ttapera/RBC/data/bids_dataset/sub-80010/ses-PNC2/fmap/sub-80010_ses-PNC2_phase2.json
# /storage/ttapera/RBC/data/bids_dataset/sub-80010/ses-PNC2/fmap/sub-80010_ses-PNC2_magnitude1.nii.gz
# /storage/ttapera/RBC/data/bids_dataset/sub-80010/ses-PNC2/fmap/sub-80010_ses-PNC2_magnitude2.nii.gz
# /storage/ttapera/RBC/data/bids_dataset/sub-80010/ses-PNC2/fmap/sub-80010_ses-PNC2_magnitude1.json
# /storage/ttapera/RBC/data/bids_dataset/sub-80010/ses-PNC2/fmap/sub-80010_ses-PNC2_phase2.nii.gz
# /storage/ttapera/RBC/data/bids_dataset/sub-80010/ses-PNC2/fmap/sub-80010_ses-PNC2_magnitude2.json
# renaming file  sub-80010_ses-PNC1_T1w.nii.gz
# renaming file  sub-80010_ses-PNC1_T1w.json
# renaming file  sub-80010_ses-PNC1_task-rest_acq-singleband_bold.json
# renaming file  sub-80010_ses-PNC1_task-rest_acq-singleband_bold.nii.gz
# renaming file  sub-80010_ses-PNC1_run-02_dwi.bval
# renaming file  sub-80010_ses-PNC1_run-01_dwi.nii.gz
# renaming file  sub-80010_ses-PNC1_run-02_dwi.nii.gz
# renaming file  sub-80010_ses-PNC1_run-02_dwi.bvec
# renaming file  sub-80010_ses-PNC1_run-01_dwi.bval
# renaming file  sub-80010_ses-PNC1_run-02_dwi.json
# renaming file  sub-80010_ses-PNC1_run-01_dwi.json
# renaming file  sub-80010_ses-PNC1_run-01_dwi.bvec
# renaming file  sub-80010_ses-PNC2_T1w.json
# renaming file  sub-80010_ses-PNC2_T1w.nii.gz
# renaming file  sub-80010_ses-PNC2_task-rest_acq-singleband_bold.json
# renaming file  sub-80010_ses-PNC2_task-rest_acq-singleband_bold.nii.gz
# renaming file  sub-80010_ses-PNC2_phase1.nii.gz
# renaming file  sub-80010_ses-PNC2_phase1.json
# renaming file  sub-80010_ses-PNC2_phase2.json
# renaming file  sub-80010_ses-PNC2_magnitude1.nii.gz
# renaming file  sub-80010_ses-PNC2_magnitude2.nii.gz
# renaming file  sub-80010_ses-PNC2_magnitude1.json
# renaming file  sub-80010_ses-PNC2_phase2.nii.gz
# renaming file  sub-80010_ses-PNC2_magnitude2.json
# Checking for successful download in  /storage/ttapera/RBC/data/bids_dataset/sub-*/ses-*/*/*
# /storage/ttapera/RBC/data/bids_dataset/sub-foofie/ses-PNC1/anat/sub-foofie_ses-PNC1_T1w.nii.gz
# /storage/ttapera/RBC/data/bids_dataset/sub-foofie/ses-PNC1/func/sub-foofie_ses-PNC1_task-rest_acq-singleband_bold.nii.gz
# /storage/ttapera/RBC/data/bids_dataset/sub-foofie/ses-PNC1/dwi/sub-foofie_ses-PNC1_run-02_dwi.nii.gz
# /storage/ttapera/RBC/data/bids_dataset/sub-foofie/ses-PNC1/dwi/sub-foofie_ses-PNC1_run-01_dwi.nii.gz
# /storage/ttapera/RBC/data/bids_dataset/sub-foofie/ses-PNC2/anat/sub-foofie_ses-PNC2_T1w.nii.gz
# /storage/ttapera/RBC/data/bids_dataset/sub-foofie/ses-PNC2/func/sub-foofie_ses-PNC2_task-rest_acq-singleband_bold.nii.gz
# /storage/ttapera/RBC/data/bids_dataset/sub-foofie/ses-PNC2/fmap/sub-foofie_ses-PNC2_magnitude1.nii.gz
# /storage/ttapera/RBC/data/bids_dataset/sub-foofie/ses-PNC2/fmap/sub-foofie_ses-PNC2_magnitude2.nii.gz
# /storage/ttapera/RBC/data/bids_dataset/sub-foofie/ses-PNC2/fmap/sub-foofie_ses-PNC2_phase2.nii.gz
# /storage/ttapera/RBC/data/bids_dataset/sub-foofie/ses-PNC2/fmap/sub-foofie_ses-PNC2_phase1.nii.gz
# True

# %%
ids = pd.read_csv('/storage/ttapera/RBC/data/bblids_3.csv', header=None, names=['bblid', 'hash', 'full_id', 'process'])

# %%
ids
# Out:
#        bblid        hash         full_id  process
# 0      80010  1832999514  sub-1832999514     True
# 1      80179  2216595430  sub-2216595430     True
# 2      80199  1867827374  sub-1867827374     True
# 3      80208   278814796   sub-278814796     True
# 4      80249  3103368139  sub-3103368139     True
# ...      ...         ...             ...      ...
# 1596  139490  1012530688  sub-1012530688     True
# 1597  139496  3726299659  sub-3726299659     True
# 1598  139532  1919055552  sub-1919055552     True
# 1599  139538  3810009389  sub-3810009389     True
# 1600  139553  3671045126  sub-3671045126     True
#
# [1601 rows x 4 columns]

# %%
complete = pd.read_csv('/storage/ttapera/RBC/data/completed.txt', header=1, names=['hash', 'download_error', 'check_error', 'date'])

# %%
complete
# Out:
#             hash  download_error  check_error                          date
# 0     1344101127               0            0  Fri May 29 17:26:12 EDT 2020
# 1     1818459775               0            0  Fri May 29 17:26:16 EDT 2020
# 2     2748427955               0            0  Fri May 29 17:26:45 EDT 2020
# 3      278814796               0            0  Fri May 29 17:32:43 EDT 2020
# 4     1867827374               1            0  Fri May 29 17:33:23 EDT 2020
# ...          ...             ...          ...                           ...
# 1999  3810009389               0            0  Wed Jun  3 16:38:37 EDT 2020
# 2000  1919055552               0            0  Wed Jun  3 16:38:37 EDT 2020
# 2001  3671045126               0            0  Wed Jun  3 16:40:37 EDT 2020
# 2002  1762102677               1            0  Wed Jun  3 21:14:14 EDT 2020
# 2003   676758900               1            0  Wed Jun  3 21:15:52 EDT 2020
#
# [2004 rows x 4 columns]

# %%
remaining = ids.copy()

# %%
done = list(set(complete.hash.values))

# %%
done
# Out:
# [1303822344,
#  574930953,
#  2933325835,
#  3225665554,
#  3675176980,
#  473767958,
#  716537879,
#  3337257001,
#  3207921706,
#  620265516,
#  351109165,
#  4242587695,
#  2404507707,
#  1307181116,
#  1892704317,
#  1162141764,
#  1139941451,
#  278814796,
#  2715820110,
#  3822559318,
#  1150591062,
#  3123429468,
#  2171240541,
#  3706183788,
#  3530244209,
#  277233792,
#  1030193285,
#  3806576780,
#  443334800,
#  533823633,
#  105914514,
#  4095893651,
#  1829191843,
#  794058926,
#  494764211,
#  2670354621,
#  3458965699,
#  3655426254,
#  2508284118,
#  3829047511,
#  1645871327,
#  977404127,
#  2258551019,
#  192413932,
#  2593612027,
#  2818302209,
#  255246595,
#  2323472643,
#  2828263690,
#  2543780112,
#  4090691856,
#  754671892,
#  2192302358,
#  1342685465,
#  2097242394,
#  1381671196,
#  447775004,
#  1221640483,
#  1440768299,
#  3996598573,
#  3810009389,
#  385564988,
#  2100052286,
#  1417920839,
#  433029449,
#  2726043986,
#  1547321683,
#  3902996821,
#  997818717,
#  292946269,
#  1057423710,
#  2933490015,
#  2433433960,
#  609583468,
#  500081009,
#  3925565817,
#  2485879167,
#  272785799,
#  962036104,
#  1512563087,
#  2832458131,
#  2762662297,
#  3495559578,
#  2392768937,
#  4066124203,
#  3846816171,
#  3437461935,
#  1860870575,
#  2319442352,
#  1679688116,
#  1643725238,
#  3612049856,
#  2023285198,
#  3236504015,
#  1502224855,
#  4099736023,
#  2886590951,
#  2412716526,
#  52306425,
#  681935372,
#  2714001943,
#  510706202,
#  1687224870,
#  1686389288,
#  1934623281,
#  2539774514,
#  975856179,
#  2170880573,
#  2000585278,
#  2292204095,
#  1334116930,
#  2172281415,
#  4069098061,
#  4033561173,
#  1340072536,
#  4286784089,
#  43606631,
#  1830789740,
#  2819146349,
#  2003542642,
#  2507776631,
#  903529086,
#  409133707,
#  1885577882,
#  4259136159,
#  1161831083,
#  3443950251,
#  981492397,
#  3443753647,
#  947782339,
#  320127697,
#  507224785,
#  3104080596,
#  163259093,
#  880296671,
#  3212763876,
#  1433666289,
#  4177765106,
#  3175244541,
#  2305221381,
#  1250648840,
#  2454545162,
#  1157595916,
#  3073794839,
#  3761349403,
#  3410682651,
#  3340124957,
#  82699044,
#  1402618672,
#  3840869169,
#  2726208310,
#  2689188662,
#  443900734,
#  3753452353,
#  1050116930,
#  2435244873,
#  2976850765,
#  3704095570,
#  3531047767,
#  657998684,
#  467305309,
#  3545637731,
#  51217255,
#  4040147816,
#  1682850665,
#  4284367721,
#  4108002155,
#  3694822252,
#  1991951207,
#  3117409134,
#  3377759088,
#  4122649464,
#  1592697722,
#  1235977088,
#  812909443,
#  4292903812,
#  3520758666,
#  2397365139,
#  2249335715,
#  768254884,
#  4163093414,
#  77390767,
#  219325366,
#  3984163767,
#  1838048191,
#  3103368139,
#  3452453842,
#  619635668,
#  1512440794,
#  375686109,
#  1996891106,
#  405373926,
#  3925705705,
#  1636295669,
#  3809027065,
#  2650375172,
#  3807880204,
#  2404418579,
#  1989985299,
#  2340561949,
#  1531348005,
#  2134697000,
#  1687315516,
#  1521763392,
#  4172833860,
#  3511452762,
#  1525589082,
#  1705895007,
#  906347615,
#  3749102689,
#  1922557027,
#  1998578790,
#  3316130924,
#  2311595124,
#  3730474103,
#  537502840,
#  1744430207,
#  2982184070,
#  3370689672,
#  1060668554,
#  3830031504,
#  1814037649,
#  4285301913,
#  1770415263,
#  1901159589,
#  2894537898,
#  4080403633,
#  29811890,
#  2420532406,
#  2112119995,
#  2085520575,
#  481928384,
#  1547584703,
#  2929280193,
#  2824389829,
#  70214854,
#  1604003015,
#  1471046861,
#  2202346713,
#  1560233178,
#  306816217,
#  3569165538,
#  3059148008,
#  920823026,
#  1299596535,
#  3327313154,
#  2654954754,
#  1313957126,
#  3538085126,
#  3290096905,
#  978838797,
#  348742929,
#  2171168019,
#  1279886614,
#  3392963865,
#  3288745244,
#  4288775453,
#  3836020010,
#  198051119,
#  107578676,
#  765502775,
#  2740569399,
#  3362293049,
#  584328521,
#  3194463561,
#  1660839245,
#  3539567950,
#  2657764686,
#  482239832,
#  2625488221,
#  3234489701,
#  1695950181,
#  924632425,
#  131655018,
#  3901605230,
#  2511291760,
#  1605617010,
#  676758900,
#  1786758517,
#  4113794425,
#  3447842173,
#  4250731906,
#  2269734277,
#  1526154632,
#  2180081033,
#  1654523276,
#  2625914260,
#  2721211800,
#  764315034,
#  1216701855,
#  956032422,
#  2413176236,
#  3236644272,
#  3481634232,
#  1656931768,
#  2047559103,
#  2991801804,
#  4205323727,
#  3250922962,
#  4099417558,
#  1506379233,
#  2919917027,
#  4215014897,
#  4113417726,
#  2876352000,
#  2755175939,
#  2423596559,
#  1065666069,
#  2446607895,
#  2871739930,
#  413107749,
#  1161373229,
#  3445089839,
#  374130224,
#  1228891697,
#  194324018,
#  858211894,
#  233932345,
#  1336976954,
#  4208420410,
#  1649501759,
#  1531930180,
#  2200266312,
#  736568905,
#  952845911,
#  396928608,
#  1485727346,
#  3931956861,
#  4083828352,
#  3338094212,
#  2263443077,
#  158779019,
#  299894413,
#  3535898260,
#  831211165,
#  2148378283,
#  2390107820,
#  1649551035,
#  3605497536,
#  1804076739,
#  3748226758,
#  1616242378,
#  4211615439,
#  3441116881,
#  2671429330,
#  2748843731,
#  4174857942,
#  1506723543,
#  1134044888,
#  1496827612,
#  3498378981,
#  666666729,
#  3498010347,
#  1829488364,
#  307169010,
#  2207352563,
#  3486713588,
#  176129790,
#  2625808132,
#  688334597,
#  281446151,
#  93800202,
#  2943493898,
#  2539603725,
#  200066829,
#  1240942354,
#  4144391965,
#  4026910516,
#  1156073272,
#  3870295870,
#  1569318720,
#  803514179,
#  488302404,
#  2435041096,
#  3177113419,
#  610158411,
#  2428446542,
#  402523989,
#  1511417686,
#  1081730904,
#  4039829353,
#  3171575673,
#  606185341,
#  3342182273,
#  2939479952,
#  3213518740,
#  3470362520,
#  3092187032,
#  624076698,
#  2022868892,
#  3218515872,
#  462702505,
#  1222330281,
#  881641391,
#  1572161461,
#  4290234295,
#  1908959165,
#  1795409854,
#  3249817543,
#  1942988748,
#  287967180,
#  2375649228,
#  766617571,
#  1467713509,
#  2967570405,
#  2851612661,
#  1280157702,
#  2449123338,
#  471230479,
#  1177503761,
#  362293270,
#  779151395,
#  2823833643,
#  3917203499,
#  3066751024,
#  154667058,
#  4238772277,
#  2928085046,
#  2170759229,
#  432187454,
#  3321849919,
#  1513736265,
#  4100540491,
#  377178190,
#  2734016600,
#  1070737504,
#  1304389731,
#  415148142,
#  3133368442,
#  1489422464,
#  1337936015,
#  1084860562,
#  1915807892,
#  2184988827,
#  826730657,
#  1594198178,
#  1867827374,
#  3354511550,
#  1006151876,
#  1384982728,
#  2932582600,
#  1046399178,
#  1991567562,
#  3241674953,
#  2112415953,
#  2996472019,
#  485017822,
#  1403873511,
#  361728233,
#  1204013299,
#  4284483827,
#  1101490424,
#  1841154314,
#  2706712860,
#  597625120,
#  1748232481,
#  2785454369,
#  1890822437,
#  3930335526,
#  460925240,
#  863570233,
#  4184549693,
#  1437821247,
#  2672167232,
#  3683182920,
#  2254317902,
#  3678218578,
#  1236117854,
#  1007995238,
#  646981992,
#  4264683889,
#  964422005,
#  3815131512,
#  2060298621,
#  2670840190,
#  4268231041,
#  1621617031,
#  1762027912,
#  1708583305,
#  1566869901,
#  2359486867,
#  3323308438,
#  2705533334,
#  2180688285,
#  1201047966,
#  3467479455,
#  476252579,
#  1871767977,
#  2763114922,
#  2588125611,
#  1477683629,
#  3669543341,
#  2017765808,
#  2893679025,
#  4198853043,
#  195168692,
#  1827965364,
#  3869583798,
#  4190603704,
#  1412450749,
#  520579518,
#  2051099070,
#  1648798153,
#  2688141773,
#  4137052624,
#  741738961,
#  3482208722,
#  1310206420,
#  1137076695,
#  3778234840,
#  3567315418,
#  2658232795,
#  2333477346,
#  396724706,
#  500214245,
#  3220670955,
#  3549161979,
#  699288066,
#  731048453,
#  3880233477,
#  2906925573,
#  3769010696,
#  3743427092,
#  2166835733,
#  3991005721,
#  2711538206,
#  1467419170,
#  248138276,
#  1457842729,
#  272468530,
#  348711479,
#  2791148092,
#  2649991749,
#  31361606,
#  1133357643,
#  1852377689,
#  4167756410,
#  3428149887,
#  276761217,
#  3876784770,
#  1378634377,
#  1630775946,
#  4093356685,
#  578652819,
#  335104664,
#  1481550494,
#  2365721251,
#  3647998632,
#  2240703148,
#  3512003246,
#  1569761975,
#  3477990078,
#  1483500237,
#  2533255886,
#  3014879953,
#  3459140306,
#  373574366,
#  3544869608,
#  4099541746,
#  2529143538,
#  1887390452,
#  4196502261,
#  1812622069,
#  636218109,
#  3410668296,
#  2058693392,
#  3140512536,
#  1113295648,
#  2087996196,
#  894864165,
#  1222568744,
#  2691009321,
#  487664430,
#  3712060241,
#  250211156,
#  2248403809,
#  3293621097,
#  2318003050,
#  2781760374,
#  499092343,
#  865069950,
#  1781205887,
#  1000393599,
#  2808974219,
#  3346107281,
#  2925300630,
#  3131141015,
#  1190308761,
#  1357417369,
#  3492490140,
#  831081379,
#  3470445476,
#  2285120424,
#  1254730664,
#  1799875502,
#  1678076849,
#  3644730316,
#  1764158413,
#  49408975,
#  1238756309,
#  1654508502,
#  1735338986,
#  905292781,
#  3744541693,
#  969649154,
#  3245755395,
#  2970389523,
#  458296344,
#  2074348568,
#  1163553824,
#  3914722336,
#  2424990755,
#  2499963942,
#  2939120682,
#  1469221931,
#  1794346030,
#  192039987,
#  443632695,
#  3297348664,
#  893070403,
#  3192540230,
#  594496588,
#  440314957,
#  2312088658,
#  360459346,
#  3539717209,
#  3818720350,
#  2308648032,
#  3332328549,
#  629271662,
#  2842709105,
#  661613686,
#  1497934968,
#  3017936002,
#  3317140614,
#  1039936647,
#  375475352,
#  1447464089,
#  1391684772,
#  1039797417,
#  759622826,
#  420900014,
#  2518846638,
#  926616751,
#  2729807028,
#  228519096,
#  1120521402,
#  3670092995,
#  985910486,
#  3621702873,
#  1088695522,
#  978316517,
#  2242628840,
#  3170512105,
#  1120275692,
#  3214822644,
#  1446259968,
#  3438308617,
#  3185151244,
#  2321665294,
#  834809108,
#  78982423,
#  194293030,
#  2691116331,
#  1826680116,
#  1091857727,
#  3565014343,
#  3090132303,
#  3022646611,
#  1238240598,
#  1653206368,
#  2990984557,
#  669437295,
#  4196412787,
#  2816126335,
#  471903637,
#  1762102677,
#  2437115295,
#  4118326689,
#  2131488178,
#  3906186680,
#  3138342343,
#  1823231434,
#  97005004,
#  1861299663,
#  4288368085,
#  1125207511,
#  1310346718,
#  1494969836,
#  2967555571,
#  2739408373,
#  324718088,
#  3150163478,
#  2972126748,
#  3607981599,
#  1930702369,
#  3932933674,
#  818654763,
#  3112586807,
#  360427065,
#  62582335,
#  2402029124,
#  4269796936,
#  2647862856,
#  978955855,
#  3733778000,
#  337120853,
#  2256834144,
#  1992060521,
#  1394077291,
#  856706691,
#  1724567179,
#  972336786,
#  2167615125,
#  2753998487,
#  296947353,
#  1852239521,
#  2240499373,
#  2225237681,
#  4031942322,
#  2748427955,
#  379170502,
#  2646855369,
#  375434957,
#  363441871,
#  699682516,
#  233205461,
#  3123810007,
#  1905979097,
#  1836756700,
#  2896375520,
#  1710493410,
#  2947976933,
#  1858784998,
#  3260960488,
#  2895974122,
#  3221434093,
#  410808047,
#  1977306864,
#  1887252222,
#  3566300931,
#  3925151495,
#  2394345225,
#  1169616649,
#  634597131,
#  2799972108,
#  1779232530,
#  4060589852,
#  1697787695,
#  1637723952,
#  909152050,
#  2860715826,
#  782651188,
#  2235019065,
#  3747270459,
#  429608771,
#  100527940,
#  1752698697,
#  662466380,
#  2877714252,
#  1170788175,
#  3029167955,
#  4187598678,
#  3062402909,
#  1048162151,
#  1196527465,
#  2215153516,
#  2978762615,
#  372100986,
#  1767985023,
#  1997401992,
#  2979786632,
#  2709385105,
#  2133389205,
#  2180976537,
#  3451752350,
#  924815264,
#  2336714673,
#  1299713973,
#  3891810238,
#  3298815936,
#  3870273492,
#  2657079253,
#  915599319,
#  1857834970,
#  2852081635,
#  2216595430,
#  1185574887,
#  3867430894,
#  2645905397,
#  1735315447,
#  749654008,
#  1963601913,
#  835121147,
#  3921457149,
#  2066354189,
#  2675724304,
#  1172262944,
#  4199436321,
#  2355359789,
#  2696622128,
#  352505908,
#  2614145086,
#  3234328642,
#  211169351,
#  4083814481,
#  1060532313,
#  3376877661,
#  2311827557,
#  3247943782,
#  3091738725,
#  612700286,
#  2723385487,
#  3016118416,
#  2742726803,
#  1631350938,
#  2041229468,
#  392818846,
#  3917353122,
#  919679140,
#  747098283,
#  80982198,
#  3235320003,
#  1220374725,
#  3866325191,
#  2361299150,
#  1743802575,
#  1533767893,
#  771616981,
#  2788528349,
#  1960268000,
#  4285804772,
#  3128815857,
#  3450122487,
#  1870893305,
#  793702653,
#  2305446143,
#  3231527178,
#  2664902924,
#  3117043986,
#  1924149526,
#  2739925272,
#  1453109530,
#  2333937949,
#  1037644062,
#  2589790495,
#  3082686752,
#  361460013,
#  2262929710,
#  2146308400,
#  2319274290,
#  4269306166,
#  1861767482,
#  232853819,
#  1790488894,
#  4231164226,
#  3756388677,
#  417075525,
#  3972288841,
#  2425606479,
#  3100094802,
#  1204359507,
#  309129555,
#  661770582,
#  3194237272,
#  1110356321,
#  401879401,
#  3190862186,
#  3245338991,
#  3373396339,
#  2880229752,
#  4160147836,
#  465465726,
#  890147203,
#  74920331,
#  746172812,
#  1615516059,
#  2151592349,
#  1904603550,
#  130118047,
#  1492693407,
#  308228517,
#  3722539437,
#  3533959599,
#  1638715823,
#  2038321583,
#  3874353588,
#  1457648056,
#  2175676858,
#  2537779643,
#  2901356997,
#  3345297865,
#  2462036439,
#  2906198493,
#  383103459,
#  3439727076,
#  55710183,
#  1929155048,
#  2795844072,
#  2398605805,
#  1137996270,
#  2033463791,
#  1095340536,
#  11407866,
#  4197093898,
#  3726299659,
#  4117238293,
#  4276974103,
#  950661655,
#  3744723479,
#  370053661,
#  2026754591,
#  965145125,
#  3762475569,
#  734794291,
#  486404664,
#  3696718394,
#  1586254402,
#  2620895813,
#  2748158536,
#  1761473096,
#  3279245901,
#  787911250,
#  3506926170,
#  349934174,
#  3359871584,
#  3637736036,
#  756380264,
#  3093541482,
#  1877783147,
#  2710418039,
#  134279804,
#  486306438,
#  3620213387,
#  283366029,
#  2933854864,
#  4040716945,
#  1819013777,
#  2200670875,
#  3818082974,
#  1214132906,
#  1293529777,
#  3814863545,
#  3266753211,
#  1604268733,
#  2718945982,
#  2117857991,
#  4164375240,
#  2680509132,
#  3060404940,
#  1696518862,
#  4216533717,
#  2780566236,
#  438637277,
#  37835493,
#  1859900144,
#  530789110,
#  3978744570,
#  3608113928,
#  1308201745,
#  3985888022,
#  322458406,
#  3081556774,
#  3950621480,
#  470135601,
#  3993637691,
#  192271174,
#  3859141450,
#  1023701836,
#  1094939473,
#  1476023122,
#  3506213723,
#  3277181789,
#  3809989470,
#  2791617373,
#  2112189288,
#  1114035056,
#  677581716,
#  3032863642,
#  3882431387,
#  1910420386,
#  2626581416,
#  2165388202,
#  1924109233,
#  941151156,
#  550810566,
#  3147576269,
#  3703469018,
#  2758144993,
#  2613113832,
#  2129564650,
#  4172321775,
#  3381441522,
#  527463413,
#  121697273,
#  2588038141,
#  2490635263,
#  3867546625,
#  3671045126,
#  902534154,
#  ...]

# %%
df_remaining = remaining[~remaining.hash.isin(done)]

# %%
df_remaining
# Out:
# Empty DataFrame
# Columns: [bblid, hash, full_id, process]
# Index: []

# %%
#df_remaining.to_csv('/storage/ttapera/RBC/data/incomplete.csv', index=False, header=False)

# %%
complete = pd.read_csv('/storage/ttapera/RBC/data/completed.txt', header=1, names=['hash', 'download_error', 'check_error', 'date'])

# %%
complete
# Out:
#             hash  download_error  check_error                          date
# 0     1344101127               0            0  Fri May 29 17:26:12 EDT 2020
# 1     1818459775               0            0  Fri May 29 17:26:16 EDT 2020
# 2     2748427955               0            0  Fri May 29 17:26:45 EDT 2020
# 3      278814796               0            0  Fri May 29 17:32:43 EDT 2020
# 4     1867827374               1            0  Fri May 29 17:33:23 EDT 2020
# ...          ...             ...          ...                           ...
# 1999  3810009389               0            0  Wed Jun  3 16:38:37 EDT 2020
# 2000  1919055552               0            0  Wed Jun  3 16:38:37 EDT 2020
# 2001  3671045126               0            0  Wed Jun  3 16:40:37 EDT 2020
# 2002  1762102677               1            0  Wed Jun  3 21:14:14 EDT 2020
# 2003   676758900               1            0  Wed Jun  3 21:15:52 EDT 2020
#
# [2004 rows x 4 columns]

# %%
complete_filtered = complete.drop_duplicates(subset=['hash'])

# %%
complete_filtered
# Out:
#             hash  download_error  check_error                          date
# 0     1344101127               0            0  Fri May 29 17:26:12 EDT 2020
# 1     1818459775               0            0  Fri May 29 17:26:16 EDT 2020
# 2     2748427955               0            0  Fri May 29 17:26:45 EDT 2020
# 3      278814796               0            0  Fri May 29 17:32:43 EDT 2020
# 4     1867827374               1            0  Fri May 29 17:33:23 EDT 2020
# ...          ...             ...          ...                           ...
# 1999  3810009389               0            0  Wed Jun  3 16:38:37 EDT 2020
# 2000  1919055552               0            0  Wed Jun  3 16:38:37 EDT 2020
# 2001  3671045126               0            0  Wed Jun  3 16:40:37 EDT 2020
# 2002  1762102677               1            0  Wed Jun  3 21:14:14 EDT 2020
# 2003   676758900               1            0  Wed Jun  3 21:15:52 EDT 2020
#
# [1601 rows x 4 columns]

# %%
bad_download = complete_filtered[complete_filtered['download_error'] == 1]

# %%
bad_t1 = complete_filtered[complete_filtered['check_error'] == 1]

# %%
bad_download
# Out:
#             hash  download_error  check_error                          date
# 4     1867827374               1            0  Fri May 29 17:33:23 EDT 2020
# 27    1604003015               1            0  Fri May 29 17:59:21 EDT 2020
# 32    2861717830               1            0  Fri May 29 18:06:24 EDT 2020
# 38    1103118018               1            0  Fri May 29 18:16:52 EDT 2020
# 39    2441231201               1            0  Fri May 29 18:17:00 EDT 2020
# ...          ...             ...          ...                           ...
# 1990  2038321583               1            0  Wed Jun  3 16:30:55 EDT 2020
# 1992  1012530688               1            1  Wed Jun  3 16:31:41 EDT 2020
# 1996  1939119029               1            0  Wed Jun  3 16:36:05 EDT 2020
# 2002  1762102677               1            0  Wed Jun  3 21:14:14 EDT 2020
# 2003   676758900               1            0  Wed Jun  3 21:15:52 EDT 2020
#
# [262 rows x 4 columns]

# %%
bad_t1
# Out:
#             hash  download_error  check_error                          date
# 120   1822850038               1            1  Fri May 29 20:18:19 EDT 2020
# 121    408967257               1            1  Fri May 29 20:19:55 EDT 2020
# 131   2134697000               1            1  Fri May 29 20:38:21 EDT 2020
# 172   1929155048               0            1  Fri May 29 21:41:30 EDT 2020
# 198   2146308400               1            1  Fri May 29 22:28:39 EDT 2020
# ...          ...             ...          ...                           ...
# 1903   978838797               0            1  Wed Jun  3 15:04:19 EDT 2020
# 1912  3439662539               0            1  Wed Jun  3 15:11:46 EDT 2020
# 1971  2672167232               0            1  Wed Jun  3 16:13:06 EDT 2020
# 1979  2723385487               1            1  Wed Jun  3 16:22:33 EDT 2020
# 1992  1012530688               1            1  Wed Jun  3 16:31:41 EDT 2020
#
# [83 rows x 4 columns]

# %%
cond1 = complete_filtered['check_error'] == 1
cond2 = complete_filtered['download_error'] == 1
complete_filtered[cond1 & cond2].shape
# Out:
# (57, 4)
