# %%
from bids import BIDSLayout

# %%
data = BIDSLayout('../data/1604003015/bids_dataset/')

# %%
data.to_df()
# Out:
# entity                                               path datatype extension  \
# 0       /storage/ttapera/RBC/data/1604003015/bids_data...      NaN      json
# 1       /storage/ttapera/RBC/data/1604003015/bids_data...     anat      json
# 2       /storage/ttapera/RBC/data/1604003015/bids_data...     anat    nii.gz
# 3       /storage/ttapera/RBC/data/1604003015/bids_data...     fmap      json
# 4       /storage/ttapera/RBC/data/1604003015/bids_data...     fmap    nii.gz
# 5       /storage/ttapera/RBC/data/1604003015/bids_data...     fmap      json
# 6       /storage/ttapera/RBC/data/1604003015/bids_data...     fmap    nii.gz
# 7       /storage/ttapera/RBC/data/1604003015/bids_data...     fmap      json
# 8       /storage/ttapera/RBC/data/1604003015/bids_data...     fmap    nii.gz
# 9       /storage/ttapera/RBC/data/1604003015/bids_data...     fmap      json
# 10      /storage/ttapera/RBC/data/1604003015/bids_data...     fmap    nii.gz
#
# entity        fmap session subject       suffix
# 0              NaN     NaN     NaN  description
# 1              NaN    PNC1   81231          T1w
# 2              NaN    PNC1   81231          T1w
# 3              NaN    PNC1   81231   magnitude1
# 4       magnitude1    PNC1   81231   magnitude1
# 5              NaN    PNC1   81231   magnitude2
# 6       magnitude2    PNC1   81231   magnitude2
# 7              NaN    PNC1   81231       phase1
# 8           phase1    PNC1   81231       phase1
# 9              NaN    PNC1   81231       phase2
# 10          phase2    PNC1   81231       phase2

# %%
data.validate
# Out:
# True

# %%
t1 = data.get(suffix = 'T1w', extension='nii.gz')

# %%
t1[0].path
# Out:
# '/storage/ttapera/RBC/data/1604003015/bids_dataset/sub-81231/ses-PNC1/anat/sub-81231_ses-PNC1_T1w.nii.gz'

# %% [markdown]
# Can we replicate the same on Flywheel? Something to consider...
#
# For now, a utility for refacing the T1 for each subject:

# %%
import flywheel
import subprocess
import os

# %%
client = flywheel.Client()

subject_label = 'sub-NDARBK082PDD'

project_label = 'ReproBrainChart'

proj = client.projects.find_first('label="ReproBrainChart"')

# %%
subjects = proj.subjects()

# %%
len(subjects)
# Out:
# 5654

# %%
sub = client.lookup('bbl/{}/{}'.format(project_label, subject_label))

# %%
sessions = [client.get(x.id) for x in sub.sessions()]

# %%
sessions
# Out:
# [{'age': None,
#   'analyses': [{'created': datetime.datetime(2020, 5, 24, 20, 49, 58, 924000, tzinfo=tzutc()),
#                 'description': None,
#                 'files': [],
#                 'gear_info': {'category': 'analysis',
#                               'id': '5e62bf29830eb917ee084492',
#                               'name': 'fw-heudiconv',
#                               'version': '0.2.11_0.2.4'},
#                 'id': '5ecaddf61a0c1d1dbf169fb3',
#                 'info': None,
#                 'inputs': [],
#                 'job': {'attempt': 1,
#                         'compute_provider_id': '5d8ed960507ac10001ff63e4',
#                         'config': {'config': {'action': 'Validate',
#                                               'default_heuristic': '',
#                                               'do_whole_project': False,
#                                               'dry_run': False,
#                                               'extended_bids': True},
#                                    'destination': {'id': '5ecaddf61a0c1d1dbf169fb3',
#                                                    'type': 'analysis'},
#                                    'inputs': {}},
#                         'created': datetime.datetime(2020, 5, 24, 20, 49, 58, 939000, tzinfo=tzutc()),
#                         'destination': {'id': '5ecaddf61a0c1d1dbf169fb3',
#                                         'type': 'analysis'},
#                         'failure_reason': None,
#                         'gear_id': '5e62bf29830eb917ee084492',
#                         'gear_info': {'category': 'analysis',
#                                       'id': None,
#                                       'name': 'fw-heudiconv',
#                                       'version': '0.2.11_0.2.4'},
#                         'group': None,
#                         'id': '5ecaddf61a0c1d1dbf169fb4',
#                         'inputs': None,
#                         'label': '',
#                         'modified': datetime.datetime(2020, 5, 24, 20, 56, 2, 641000, tzinfo=tzutc()),
#                         'origin': {'id': 'adebimpe@upenn.edu', 'type': 'user'},
#                         'previous_job_id': None,
#                         'profile': {'elapsed_time_ms': 26966,
#                                     'executor': {'cpu_cores': 8,
#                                                  'disk_bytes': None,
#                                                  'gpu': None,
#                                                  'host': None,
#                                                  'instance_type': None,
#                                                  'memory_bytes': 54869778432,
#                                                  'name': 'upenn-center-fmriprep-757f58b5',
#                                                  'swap_bytes': 32212250624},
#                                     'preparation_time_ms': None,
#                                     'total_input_files': 0,
#                                     'total_input_size_bytes': 0,
#                                     'total_output_files': 0,
#                                     'total_output_size_bytes': 0,
#                                     'total_time_ms': 27101,
#                                     'upload_time_ms': None,
#                                     'versions': {'core': '11.3.4'}},
#                         'project': None,
#                         'related_container_ids': ['5dc1d8b1e74aa3005e0dbec7',
#                                                   '5dd6c018e74aa3005a0b656a',
#                                                   'bbl',
#                                                   '5ecaddf61a0c1d1dbf169fb3',
#                                                   '5dd6c01ae74aa3005c18a6ee'],
#                         'request': {'inputs': [{'location': '/',
#                                                 'type': 'docker',
#                                                 'uri': 'upenn.flywheel.io/fw-heudiconv@sha256:00598ef2a98af61d119e9f59a0a466d2af327425b4466117a13ae23340c8b44a',
#                                                 'vu': None},
#                                                {'location': '/flywheel/v0',
#                                                 'type': 'scitran',
#                                                 'uri': '/jobs/5ecaddf61a0c1d1dbf169fb4/config.json',
#                                                 'vu': None}],
#                                     'outputs': [{'location': '/flywheel/v0/output',
#                                                  'type': 'scitran',
#                                                  'uri': '/engine?level=analysis&id=5ecaddf61a0c1d1dbf169fb3&job=5ecaddf61a0c1d1dbf169fb4'}],
#                                     'target': {'command': ['bash',
#                                                            '-c',
#                                                            './fw_heudiconv_run.py'],
#                                                'dir': '/flywheel/v0',
#                                                'env': {'FW_CONFIG_ACTION': 'Validate',
#                                                        'FW_CONFIG_DEFAULT_HEURISTIC': '',
#                                                        'FW_CONFIG_DO_WHOLE_PROJECT': 'false',
#                                                        'FW_CONFIG_DRY_RUN': 'false',
#                                                        'FW_CONFIG_EXTENDED_BIDS': 'true',
#                                                        'PATH': '/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin'}}},
#                         'retried': None,
#                         'saved_files': [],
#                         'state': 'complete',
#                         'tags': ['analysis', 'fw-heudiconv'],
#                         'transitions': {'cancelled': None,
#                                         'complete': datetime.datetime(2020, 5, 24, 20, 56, 2, 641000, tzinfo=tzutc()),
#                                         'failed': None,
#                                         'running': datetime.datetime(2020, 5, 24, 20, 55, 35, 540000, tzinfo=tzutc())}},
#                 'label': 'heudiconv_vaildation',
#                 'modified': datetime.datetime(2020, 5, 24, 20, 56, 2, 616000, tzinfo=tzutc()),
#                 'notes': None,
#                 'parent': {'id': '5dd6c01ae74aa3005c18a6ee', 'type': 'session'},
#                 'parents': {'acquisition': None,
#                             'analysis': None,
#                             'group': 'bbl',
#                             'project': '5dc1d8b1e74aa3005e0dbec7',
#                             'session': '5dd6c01ae74aa3005c18a6ee',
#                             'subject': '5dd6c018e74aa3005a0b656a'},
#                 'revision': 3,
#                 'tags': None},
#                {'created': datetime.datetime(2020, 5, 24, 22, 3, 31, 762000, tzinfo=tzutc()),
#                 'description': None,
#                 'files': [],
#                 'gear_info': {'category': 'analysis',
#                               'id': '5ec22db354e1ef4f3d586037',
#                               'name': 'fmriprep-hpc',
#                               'version': '0.3.4_20.0.7'},
#                 'id': '5ecaef331a0c1d1e56169eee',
#                 'info': None,
#                 'inputs': [{'classification': {},
#                             'created': datetime.datetime(2020, 1, 29, 19, 1, 43, 385000, tzinfo=tzutc()),
#                             'hash': 'v0-sha384-9f0c0dfdfa33087286b4b7cbf5986a31a31e7fca42b045b3c0f77b1872999519a6ecf3c9ce5c4024b0a974074126216c',
#                             'id': '311c4712-d19b-44cd-a341-99c43c4e37e9',
#                             'info': {},
#                             'info_exists': None,
#                             'mimetype': 'text/plain',
#                             'modality': None,
#                             'modified': datetime.datetime(2020, 1, 29, 19, 1, 37, 662000, tzinfo=tzutc()),
#                             'name': 'license.txt',
#                             'origin': {'id': 'mcieslak@upenn.edu',
#                                        'method': None,
#                                        'name': None,
#                                        'type': 'user',
#                                        'via': None},
#                             'replaced': None,
#                             'size': 65,
#                             'tags': [],
#                             'type': 'text',
#                             'zip_member_count': None}],
#                 'job': {'attempt': 1,
#                         'compute_provider_id': '5d8ed960507ac10001ff63e4',
#                         'config': {'config': {'FREESURFER_LICENSE': "{'classification': "
#                                                                     '{},\n'
#                                                                     ' '
#                                                                     "'created': "
#                                                                     'datetime.datetime(2020, '
#                                                                     '1, 29, 19, '
#                                                                     '1, 43, '
#                                                                     '385000, '
#                                                                     'tzinfo=tzutc()),\n'
#                                                                     " 'hash': "
#                                                                     "'v0-sha384-9f0c0dfdfa33087286b4b7cbf5986a31a31e7fca42b045b3c0f77b1872999519a6ecf3c9ce5c4024b0a974074126216c',\n"
#                                                                     " 'id': "
#                                                                     "'311c4712-d19b-44cd-a341-99c43c4e37e9',\n"
#                                                                     " 'info': "
#                                                                     '{},\n'
#                                                                     ' '
#                                                                     "'info_exists': "
#                                                                     'None,\n'
#                                                                     ' '
#                                                                     "'mimetype': "
#                                                                     "'text/plain',\n"
#                                                                     ' '
#                                                                     "'modality': "
#                                                                     'None,\n'
#                                                                     ' '
#                                                                     "'modified': "
#                                                                     'datetime.datetime(2020, '
#                                                                     '1, 29, 19, '
#                                                                     '1, 37, '
#                                                                     '662000, '
#                                                                     'tzinfo=tzutc()),\n'
#                                                                     " 'name': "
#                                                                     "'license.txt',\n"
#                                                                     " 'origin': "
#                                                                     "{'id': "
#                                                                     "'mcieslak@upenn.edu',\n"
#                                                                     '            '
#                                                                     "'method': "
#                                                                     'None,\n'
#                                                                     '            '
#                                                                     "'name': "
#                                                                     'None,\n'
#                                                                     '            '
#                                                                     "'type': "
#                                                                     "'user',\n"
#                                                                     '            '
#                                                                     "'via': "
#                                                                     'None},\n'
#                                                                     ' '
#                                                                     "'replaced': "
#                                                                     'None,\n'
#                                                                     " 'size': "
#                                                                     '65,\n'
#                                                                     " 'tags': "
#                                                                     '[],\n'
#                                                                     " 'type': "
#                                                                     "'text',\n"
#                                                                     ' '
#                                                                     "'zip_member_count': "
#                                                                     'None}',
#                                               'anat_only': False,
#                                               'aroma_melodic_dimensionality': -200.0,
#                                               'bold2t1w_dof': 6,
#                                               'cifti_output': '91k',
#                                               'dummy_scans': 0.0,
#                                               'dvars_spike_threshold': 1.5,
#                                               'fd_spike_threshold': 0.5,
#                                               'fmap_bspline': False,
#                                               'fmap_no_demean': False,
#                                               'force_bbr': False,
#                                               'force_no_bbr': False,
#                                               'force_syn': False,
#                                               'fs_no_reconall': False,
#                                               'ignore': '',
#                                               'intermediate_files': '',
#                                               'intermediate_folders': '',
#                                               'longitudinal': False,
#                                               'low_mem': False,
#                                               'medial_surface_nan': False,
#                                               'no_submm_recon': False,
#                                               'no_track': False,
#                                               'output_spaces': 'MNI152NLin2009cAsym',
#                                               'return_all_components': False,
#                                               'save_intermediate_work': False,
#                                               'save_outputs': False,
#                                               'sge-cpu': '8',
#                                               'sge-ram': '64G',
#                                               'sge-short': False,
#                                               'singularity-debug': False,
#                                               'singularity-writable': False,
#                                               'skip_bids_validation': False,
#                                               'skull_strip_fixed_seed': False,
#                                               'skull_strip_template': 'OASIS30ANTs',
#                                               'sloppy_mode': False,
#                                               't2s_coreg': False,
#                                               'task_id': '',
#                                               'timeout': 2.0,
#                                               'use_all_sessions': False,
#                                               'use_aroma': False,
#                                               'use_syn_sdc': False},
#                                    'destination': {'id': '5ecaef331a0c1d1e56169eee',
#                                                    'type': 'analysis'},
#                                    'inputs': {'freesurfer_license': {'base': 'file',
#                                                                      'hierarchy': {'id': '5dc1d8b1e74aa3005e0dbec7',
#                                                                                    'type': 'project'},
#                                                                      'location': {'name': 'license.txt',
#                                                                                   'path': '/flywheel/v0/input/freesurfer_license/license.txt'},
#                                                                      'object': {'classification': {},
#                                                                                 'measurements': [],
#                                                                                 'mimetype': 'text/plain',
#                                                                                 'modality': None,
#                                                                                 'size': 65,
#                                                                                 'tags': [],
#                                                                                 'type': 'text'}}}},
#                         'created': datetime.datetime(2020, 5, 24, 22, 3, 31, 788000, tzinfo=tzutc()),
#                         'destination': {'id': '5ecaef331a0c1d1e56169eee',
#                                         'type': 'analysis'},
#                         'failure_reason': None,
#                         'gear_id': '5ec22db354e1ef4f3d586037',
#                         'gear_info': {'category': 'analysis',
#                                       'id': None,
#                                       'name': 'fmriprep-hpc',
#                                       'version': '0.3.4_20.0.7'},
#                         'group': None,
#                         'id': '5ecaef331a0c1d1e56169eef',
#                         'inputs': {'freesurfer_license': {'id': '5dc1d8b1e74aa3005e0dbec7',
#                                                           'name': 'license.txt',
#                                                           'type': 'project'}},
#                         'label': '',
#                         'modified': datetime.datetime(2020, 5, 24, 22, 14, 58, 947000, tzinfo=tzutc()),
#                         'origin': {'id': 'adebimpe@upenn.edu', 'type': 'user'},
#                         'previous_job_id': None,
#                         'profile': {'elapsed_time_ms': 421693,
#                                     'executor': {'cpu_cores': 16,
#                                                  'disk_bytes': None,
#                                                  'gpu': None,
#                                                  'host': None,
#                                                  'instance_type': None,
#                                                  'memory_bytes': 405194407936,
#                                                  'name': '2119fmn013',
#                                                  'swap_bytes': 4294963200},
#                                     'preparation_time_ms': None,
#                                     'total_input_files': 1,
#                                     'total_input_size_bytes': 65,
#                                     'total_output_files': 0,
#                                     'total_output_size_bytes': 0,
#                                     'total_time_ms': 683357,
#                                     'upload_time_ms': None,
#                                     'versions': {'core': '11.3.4'}},
#                         'project': None,
#                         'related_container_ids': ['5dc1d8b1e74aa3005e0dbec7',
#                                                   '5dd6c018e74aa3005a0b656a',
#                                                   'bbl',
#                                                   '5ecaef331a0c1d1e56169eee',
#                                                   '5dd6c01ae74aa3005c18a6ee'],
#                         'request': {'inputs': [{'location': '/',
#                                                 'type': 'docker',
#                                                 'uri': 'docker.io/pennbbl/fmriprep-hpc:0.3.4_20.0.7',
#                                                 'vu': None},
#                                                {'location': '/flywheel/v0',
#                                                 'type': 'scitran',
#                                                 'uri': '/jobs/5ecaef331a0c1d1e56169eef/config.json',
#                                                 'vu': None},
#                                                {'location': '/flywheel/v0/input/freesurfer_license',
#                                                 'type': 'scitran',
#                                                 'uri': '/projects/5dc1d8b1e74aa3005e0dbec7/files/license.txt',
#                                                 'vu': None}],
#                                     'outputs': [{'location': '/flywheel/v0/output',
#                                                  'type': 'scitran',
#                                                  'uri': '/engine?level=analysis&id=5ecaef331a0c1d1e56169eee&job=5ecaef331a0c1d1e56169eef'}],
#                                     'target': {'command': ['bash',
#                                                            '-c',
#                                                            './run'],
#                                                'dir': '/flywheel/v0',
#                                                'env': {'FW_CONFIG_ANAT_ONLY': 'false',
#                                                        'FW_CONFIG_AROMA_MELODIC_DIMENSIONALITY': '-200.0',
#                                                        'FW_CONFIG_BOLD2T1W_DOF': '6',
#                                                        'FW_CONFIG_CIFTI_OUTPUT': '91k',
#                                                        'FW_CONFIG_DUMMY_SCANS': '0.0',
#                                                        'FW_CONFIG_DVARS_SPIKE_THRESHOLD': '1.5',
#                                                        'FW_CONFIG_FD_SPIKE_THRESHOLD': '0.5',
#                                                        'FW_CONFIG_FMAP_BSPLINE': 'false',
#                                                        'FW_CONFIG_FMAP_NO_DEMEAN': 'false',
#                                                        'FW_CONFIG_FORCE_BBR': 'false',
#                                                        'FW_CONFIG_FORCE_NO_BBR': 'false',
#                                                        'FW_CONFIG_FORCE_SYN': 'false',
#                                                        'FW_CONFIG_FREESURFER_LICENSE': "{'classification': "
#                                                                                        '{},\n'
#                                                                                        ' '
#                                                                                        "'created': "
#                                                                                        'datetime.datetime(2020, '
#                                                                                        '1, '
#                                                                                        '29, '
#                                                                                        '19, '
#                                                                                        '1, '
#                                                                                        '43, '
#                                                                                        '385000, '
#                                                                                        'tzinfo=tzutc()),\n'
#                                                                                        ' '
#                                                                                        "'hash': "
#                                                                                        "'v0-sha384-9f0c0dfdfa33087286b4b7cbf5986a31a31e7fca42b045b3c0f77b1872999519a6ecf3c9ce5c4024b0a974074126216c',\n"
#                                                                                        ' '
#                                                                                        "'id': "
#                                                                                        "'311c4712-d19b-44cd-a341-99c43c4e37e9',\n"
#                                                                                        ' '
#                                                                                        "'info': "
#                                                                                        '{},\n'
#                                                                                        ' '
#                                                                                        "'info_exists': "
#                                                                                        'None,\n'
#                                                                                        ' '
#                                                                                        "'mimetype': "
#                                                                                        "'text/plain',\n"
#                                                                                        ' '
#                                                                                        "'modality': "
#                                                                                        'None,\n'
#                                                                                        ' '
#                                                                                        "'modified': "
#                                                                                        'datetime.datetime(2020, '
#                                                                                        '1, '
#                                                                                        '29, '
#                                                                                        '19, '
#                                                                                        '1, '
#                                                                                        '37, '
#                                                                                        '662000, '
#                                                                                        'tzinfo=tzutc()),\n'
#                                                                                        ' '
#                                                                                        "'name': "
#                                                                                        "'license.txt',\n"
#                                                                                        ' '
#                                                                                        "'origin': "
#                                                                                        "{'id': "
#                                                                                        "'mcieslak@upenn.edu',\n"
#                                                                                        '            '
#                                                                                        "'method': "
#                                                                                        'None,\n'
#                                                                                        '            '
#                                                                                        "'name': "
#                                                                                        'None,\n'
#                                                                                        '            '
#                                                                                        "'type': "
#                                                                                        "'user',\n"
#                                                                                        '            '
#                                                                                        "'via': "
#                                                                                        'None},\n'
#                                                                                        ' '
#                                                                                        "'replaced': "
#                                                                                        'None,\n'
#                                                                                        ' '
#                                                                                        "'size': "
#                                                                                        '65,\n'
#                                                                                        ' '
#                                                                                        "'tags': "
#                                                                                        '[],\n'
#                                                                                        ' '
#                                                                                        "'type': "
#                                                                                        "'text',\n"
#                                                                                        ' '
#                                                                                        "'zip_member_count': "
#                                                                                        'None}',
#                                                        'FW_CONFIG_FS_NO_RECONALL': 'false',
#                                                        'FW_CONFIG_IGNORE': '',
#                                                        'FW_CONFIG_INTERMEDIATE_FILES': '',
#                                                        'FW_CONFIG_INTERMEDIATE_FOLDERS': '',
#                                                        'FW_CONFIG_LONGITUDINAL': 'false',
#                                                        'FW_CONFIG_LOW_MEM': 'false',
#                                                        'FW_CONFIG_MEDIAL_SURFACE_NAN': 'false',
#                                                        'FW_CONFIG_NO_SUBMM_RECON': 'false',
#                                                        'FW_CONFIG_NO_TRACK': 'false',
#                                                        'FW_CONFIG_OUTPUT_SPACES': 'MNI152NLin2009cAsym',
#                                                        'FW_CONFIG_RETURN_ALL_COMPONENTS': 'false',
#                                                        'FW_CONFIG_SAVE_INTERMEDIATE_WORK': 'false',
#                                                        'FW_CONFIG_SAVE_OUTPUTS': 'false',
#                                                        'FW_CONFIG_SGECPU': '8',
#                                                        'FW_CONFIG_SGERAM': '64G',
#                                                        'FW_CONFIG_SGESHORT': 'false',
#                                                        'FW_CONFIG_SINGULARITYDEBUG': 'false',
#                                                        'FW_CONFIG_SINGULARITYWRITABLE': 'false',
#                                                        'FW_CONFIG_SKIP_BIDS_VALIDATION': 'false',
#                                                        'FW_CONFIG_SKULL_STRIP_FIXED_SEED': 'false',
#                                                        'FW_CONFIG_SKULL_STRIP_TEMPLATE': 'OASIS30ANTs',
#                                                        'FW_CONFIG_SLOPPY_MODE': 'false',
#                                                        'FW_CONFIG_T2S_COREG': 'false',
#                                                        'FW_CONFIG_TASK_ID': '',
#                                                        'FW_CONFIG_TIMEOUT': '2.0',
#                                                        'FW_CONFIG_USE_ALL_SESSIONS': 'false',
#                                                        'FW_CONFIG_USE_AROMA': 'false',
#                                                        'FW_CONFIG_USE_SYN_SDC': 'false',
#                                                        'PATH': '/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin'}}},
#                         'retried': None,
#                         'saved_files': [],
#                         'state': 'failed',
#                         'tags': ['analysis', 'fmriprep-hpc'],
#                         'transitions': {'cancelled': None,
#                                         'complete': None,
#                                         'failed': datetime.datetime(2020, 5, 24, 22, 14, 58, 947000, tzinfo=tzutc()),
#                                         'running': datetime.datetime(2020, 5, 24, 22, 3, 35, 590000, tzinfo=tzutc())}},
#                 'label': 'fmriprep-hpc_0.3.2_20.0.7',
#                 'modified': datetime.datetime(2020, 5, 24, 22, 14, 58, 773000, tzinfo=tzutc()),
#                 'notes': None,
#                 'parent': {'id': '5dd6c01ae74aa3005c18a6ee', 'type': 'session'},
#                 'parents': {'acquisition': None,
#                             'analysis': None,
#                             'group': 'bbl',
#                             'project': '5dc1d8b1e74aa3005e0dbec7',
#                             'session': '5dd6c01ae74aa3005c18a6ee',
#                             'subject': '5dd6c018e74aa3005a0b656a'},
#                 'revision': 3,
#                 'tags': None}],
#   'created': datetime.datetime(2019, 11, 21, 16, 49, 29, 337000, tzinfo=tzutc()),
#   'files': [],
#   'group': 'bbl',
#   'id': '5dd6c01ae74aa3005c18a6ee',
#   'info': {'BIDS': {'Label': 'HBNsiteRU', 'Subject': 'NDARBK082PDD'}},
#   'info_exists': None,
#   'label': 'ses-HBNsiteRU',
#   'modified': datetime.datetime(2020, 4, 24, 15, 28, 25, 741000, tzinfo=tzutc()),
#   'notes': [],
#   'operator': None,
#   'parents': {'acquisition': None,
#               'analysis': None,
#               'group': 'bbl',
#               'project': '5dc1d8b1e74aa3005e0dbec7',
#               'session': None,
#               'subject': '5dd6c018e74aa3005a0b656a'},
#   'permissions': [{'access': 'admin',
#                    'id': 'ttapera@upenn.edu',
#                    'role_ids': None},
#                   {'access': 'admin',
#                    'id': 'azeez.adebimpe5@gmail.com',
#                    'role_ids': None},
#                   {'access': 'admin',
#                    'id': 'adebimpe@upenn.edu',
#                    'role_ids': None},
#                   {'access': 'admin',
#                    'id': 'sattertt@upenn.edu',
#                    'role_ids': None},
#                   {'access': 'admin',
#                    'id': 'sattertt@gmail.com',
#                    'role_ids': None},
#                   {'access': 'admin',
#                    'id': 'mcieslak@upenn.edu',
#                    'role_ids': None},
#                   {'access': 'ro',
#                    'id': 'jenna.kantor@pennmedicine.upenn.edu',
#                    'role_ids': None},
#                   {'access': 'ro',
#                    'id': 'radreview@upenn.edu',
#                    'role_ids': None},
#                   {'access': 'rw',
#                    'id': 'eng.franco@gmail.com',
#                    'role_ids': None},
#                   {'access': 'ro',
#                    'id': 'radreview@pennbrain.upenn.edu',
#                    'role_ids': None},
#                   {'access': 'rw', 'id': 'vsydnor@upenn.edu', 'role_ids': None},
#                   {'access': 'rw', 'id': 'gbaum@upenn.edu', 'role_ids': None},
#                   {'access': 'rw', 'id': 'butellyn@upenn.edu', 'role_ids': None},
#                   {'access': 'rw', 'id': 'zaixucui@upenn.edu', 'role_ids': None},
#                   {'access': 'rw', 'id': 'diegodav@upenn.edu', 'role_ids': None},
#                   {'access': 'rw', 'id': 'moberg@upenn.edu', 'role_ids': None},
#                   {'access': 'rw', 'id': 'krmurtha@upenn.edu', 'role_ids': None},
#                   {'access': 'rw', 'id': 'kpiiwaa@upenn.edu', 'role_ids': None},
#                   {'access': 'rw', 'id': 'apines@upenn.edu', 'role_ids': None},
#                   {'access': 'rw', 'id': 'sagerush@upenn.edu', 'role_ids': None},
#                   {'access': 'rw', 'id': 'adrose@upenn.edu', 'role_ids': None},
#                   {'access': 'rw', 'id': 'rsga@upenn.edu', 'role_ids': None},
#                   {'access': 'rw', 'id': 'raquel@upenn.edu', 'role_ids': None},
#                   {'access': 'rw', 'id': 'gur@upenn.edu', 'role_ids': None},
#                   {'access': 'rw', 'id': 'tymoore@upenn.edu', 'role_ids': None},
#                   {'access': 'rw', 'id': 'gpretty@upenn.edu', 'role_ids': None},
#                   {'access': 'rw', 'id': 'roalf@upenn.edu', 'role_ids': None},
#                   {'access': 'rw', 'id': 'jschmitt@upenn.edu', 'role_ids': None},
#                   {'access': 'rw', 'id': 'scott1@upenn.edu', 'role_ids': None},
#                   {'access': 'rw',
#                    'id': 'danwolf@pennmedicine.upenn.edu',
#                    'role_ids': None},
#                   {'access': 'rw',
#                    'id': 'ailei0801@gmail.com',
#                    'role_ids': None},
#                   {'access': 'rw', 'id': 'sgiava77@gmail.com', 'role_ids': None},
#                   {'access': 'rw',
#                    'id': 'andre.zugman@gmail.com',
#                    'role_ids': None}],
#   'project': '5dc1d8b1e74aa3005e0dbec7',
#   'project_has_template': None,
#   'revision': 1156,
#   'satisfies_template': None,
#   'subject': {'age': None,
#               'analyses': None,
#               'code': 'sub-NDARBK082PDD',
#               'cohort': None,
#               'created': datetime.datetime(2019, 11, 21, 16, 49, 28, 33000, tzinfo=tzutc()),
#               'ethnicity': None,
#               'files': None,
#               'firstname': None,
#               'id': '5dd6c018e74aa3005a0b656a',
#               'info': None,
#               'info_exists': None,
#               'label': 'sub-NDARBK082PDD',
#               'lastname': None,
#               'master_code': None,
#               'modified': datetime.datetime(2020, 4, 24, 15, 28, 25, 741000, tzinfo=tzutc()),
#               'notes': None,
#               'parents': {'acquisition': None,
#                           'analysis': None,
#                           'group': 'bbl',
#                           'project': '5dc1d8b1e74aa3005e0dbec7',
#                           'session': None,
#                           'subject': None},
#               'permissions': [{'access': 'admin',
#                                'id': 'ttapera@upenn.edu',
#                                'role_ids': None},
#                               {'access': 'admin',
#                                'id': 'azeez.adebimpe5@gmail.com',
#                                'role_ids': None},
#                               {'access': 'admin',
#                                'id': 'adebimpe@upenn.edu',
#                                'role_ids': None},
#                               {'access': 'admin',
#                                'id': 'sattertt@upenn.edu',
#                                'role_ids': None},
#                               {'access': 'admin',
#                                'id': 'sattertt@gmail.com',
#                                'role_ids': None},
#                               {'access': 'admin',
#                                'id': 'mcieslak@upenn.edu',
#                                'role_ids': None},
#                               {'access': 'ro',
#                                'id': 'jenna.kantor@pennmedicine.upenn.edu',
#                                'role_ids': None},
#                               {'access': 'ro',
#                                'id': 'radreview@upenn.edu',
#                                'role_ids': None},
#                               {'access': 'rw',
#                                'id': 'eng.franco@gmail.com',
#                                'role_ids': None},
#                               {'access': 'ro',
#                                'id': 'radreview@pennbrain.upenn.edu',
#                                'role_ids': None},
#                               {'access': 'rw',
#                                'id': 'vsydnor@upenn.edu',
#                                'role_ids': None},
#                               {'access': 'rw',
#                                'id': 'gbaum@upenn.edu',
#                                'role_ids': None},
#                               {'access': 'rw',
#                                'id': 'butellyn@upenn.edu',
#                                'role_ids': None},
#                               {'access': 'rw',
#                                'id': 'zaixucui@upenn.edu',
#                                'role_ids': None},
#                               {'access': 'rw',
#                                'id': 'diegodav@upenn.edu',
#                                'role_ids': None},
#                               {'access': 'rw',
#                                'id': 'moberg@upenn.edu',
#                                'role_ids': None},
#                               {'access': 'rw',
#                                'id': 'krmurtha@upenn.edu',
#                                'role_ids': None},
#                               {'access': 'rw',
#                                'id': 'kpiiwaa@upenn.edu',
#                                'role_ids': None},
#                               {'access': 'rw',
#                                'id': 'apines@upenn.edu',
#                                'role_ids': None},
#                               {'access': 'rw',
#                                'id': 'sagerush@upenn.edu',
#                                'role_ids': None},
#                               {'access': 'rw',
#                                'id': 'adrose@upenn.edu',
#                                'role_ids': None},
#                               {'access': 'rw',
#                                'id': 'rsga@upenn.edu',
#                                'role_ids': None},
#                               {'access': 'rw',
#                                'id': 'raquel@upenn.edu',
#                                'role_ids': None},
#                               {'access': 'rw',
#                                'id': 'gur@upenn.edu',
#                                'role_ids': None},
#                               {'access': 'rw',
#                                'id': 'tymoore@upenn.edu',
#                                'role_ids': None},
#                               {'access': 'rw',
#                                'id': 'gpretty@upenn.edu',
#                                'role_ids': None},
#                               {'access': 'rw',
#                                'id': 'roalf@upenn.edu',
#                                'role_ids': None},
#                               {'access': 'rw',
#                                'id': 'jschmitt@upenn.edu',
#                                'role_ids': None},
#                               {'access': 'rw',
#                                'id': 'scott1@upenn.edu',
#                                'role_ids': None},
#                               {'access': 'rw',
#                                'id': 'danwolf@pennmedicine.upenn.edu',
#                                'role_ids': None},
#                               {'access': 'rw',
#                                'id': 'ailei0801@gmail.com',
#                                'role_ids': None},
#                               {'access': 'rw',
#                                'id': 'sgiava77@gmail.com',
#                                'role_ids': None},
#                               {'access': 'rw',
#                                'id': 'andre.zugman@gmail.com',
#                                'role_ids': None}],
#               'project': '5dc1d8b1e74aa3005e0dbec7',
#               'race': None,
#               'revision': 1156,
#               'sex': None,
#               'species': None,
#               'strain': None,
#               'tags': None,
#               'type': None},
#   'tags': [],
#   'timestamp': None,
#   'timezone': None,
#   'uid': None,
#   'weight': None}]

# %%
def download_t1w(acquisition_obj, name, dest):
    '''
    download a file from an acquisition, using "dest" as the filename on disk
    '''
    
    acquisition_obj.download_file(name, dest)

# %%
def run_afni(path_to_file, filename, rec_label='refaced', dry_run=True, verbose=True):
    '''
    run afni reface, using rec_label as the value in the rec-<value> filename
    
    returns the returncode and std out
    '''
    
    assert os.path.isfile(path_to_file + filename)
    
    refaced_filename = filename.replace("_T1w.nii.gz", "_rec-{}_T1w.nii.gz".format(rec_label))
    process = ['@afni_refacer_run', '-input', path_to_file + filename ,'-mode_reface', '-prefix', path_to_file + refaced_filename]
    
    if dry_run:
        process.insert(0, 'echo')
        os.system('cp {} {}'.format(path_to_file + filename, path_to_file + refaced_filename))
    if verbose:
        print("Running:\n", " ".join(process))
    
    p = subprocess.Popen(process, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    out, err = p.communicate()
    
    if out is None:
        out = ''
    return refaced_filename, p.returncode, out

# %%
def replace_t1w(acquisition_obj, original_info, replacement_filename, replacement_path, rec_label, delete=False):
    '''
    upload a refaced T1 to an acquisition to replace an original
    
    '''
    
    info = original_info.copy()
    
    info['BIDS']['Filename'] = replacement_filename
    info['BIDS']['Rec'] = rec_label
    
    acquisition_obj.upload_file(replacement_path + replacement_filename)
    
    acquisition_obj = acquisition_obj.reload()
    
    files = acquisition_obj.files
    
    target = [f for f in files if f.name == replacement_filename].pop()
    
    acquisition_obj.update_file_info(replacement_filename, info)
    
    if delete:
        print("deleting existing T1")
        acquisition_obj.delete_file(original_info['BIDS']['Filename'])
    
    return None

# %%
def process_subject(subject_obj, out_filename=None, destination='./', rec_label='refaced', verbose = True, dry_run=True):
    '''
    Process a subject:
       
       loop over sessions, acquisitions, files
       if a T1w is found, download it
       run afni reface and create a new file with 
    '''
    sessions = subject_obj.sessions()

    for ses in sessions:

        acquisitions = [client.get(a.id) for a in ses.acquisitions()]

        for acq in acquisitions:

            for f in acq.files:

                if get_nested(f, 'info', 'BIDS', 'Modality') == 'T1w':
                    
                    out_filename = f.name if out_filename is None else out_filename
                    
                    if verbose:
                        print("T1 found: {}\n\tDownloading as {} ...".format(f.name, out_filename))
                    
                    download_t1w(acq, f.name, destination + out_filename)
                    
                    if verbose:
                        print("Running afni reface...")

                    refaced_file, status, output = run_afni(destination, out_filename, rec_label, dry_run=dry_run, verbose=verbose)
                    
                    if status != 0:
                        print("There was a problem running afni")
                        if verbose:
                            print(output)
                    else:
                        if verbose:
                            print("Afni ran successfully!")
                            print("Uploading...")
                        replace_t1w(acq, f.info, refaced_file, destination, rec_label, delete=False)

# %%
process_subject(subjects[2], out_filename='foobar_T1w.nii.gz', destination="../data/", rec_label='refaced', verbose=True, dry_run=False)
# Out:
# T1 found: sub-NDARAC904DMU_ses-HBNsiteRU_acq-HCP_T1w.nii.gz
# 	Downloading as foobar_T1w.nii.gz ...
# Running afni reface...
# Running:
#  @afni_refacer_run -input ../data/foobar_T1w.nii.gz -mode_reface -prefix ../data/foobar_rec-refaced_T1w.nii.gz
# Afni ran successfully!

# %% [markdown]
# The above works by downloading from `fw`, running reface, and then uploading. We also need a plan for finding a subject's T1w in a BIDS dir on disk, running refacer, then uploading to `fw` and deleting existing.
